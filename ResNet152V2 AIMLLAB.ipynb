# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Importing necessary packages**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import cv2
import os
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPool2D,MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# %% [markdown]
# ## **2. Load the Image Training and Validation Datasets**
#
# ### i. Get the Image Dataset Paths

# %%
train_dataset_path = '/content/drive/MyDrive/Monkeypox_Skin_Image_Dataset/Train'
validation_dataset_path = '/content/drive/MyDrive/Monkeypox_Skin_Image_Dataset/Test'

# %% [markdown]
# ### ii. Load Image Datasets and Apply Augmentations
# Since the images present in the datasets are 150x150px in size, the image height and width are taken as 150, 150 respectively. The batch size value can be changed if required.

# %%
IMG_WIDTH = 150
IMG_HEIGHT = 150
BATCH_SIZE = 32

# %% [markdown]
# Loading the training dataset and applying augmentations on it.

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                  zoom_range=0.2,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  fill_mode='nearest')
train_generator = train_datagen.flow_from_directory(train_dataset_path,
                                                   target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                   batch_size=BATCH_SIZE,
                                                   class_mode='categorical',
                                                   shuffle=True)
# Out:
# Found 541 images belonging to 4 classes.

# %% [markdown]
# Loading the validation dataset.

# %%
validation_datagen = ImageDataGenerator(rescale=1.0/255)
validation_generator = validation_datagen.flow_from_directory(validation_dataset_path,
                                                             target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                             batch_size=BATCH_SIZE,
                                                             class_mode='categorical',
                                                             shuffle=True)
# Out:
# Found 241 images belonging to 4 classes.

# %% [markdown]
# ### iii. Get the Label Mappings
# The labels dictionary is made in order to retrive the class names against the label indices used for training the model

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : Chickenpox
# 1 : Measles
# 2 : Monkeypox
# 3 : Normal

# %% [markdown]
# ## **3. Plotting Sample Training Image**s

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx = 0

for i in range(2):
    for j in range(5):
        label = labels[np.argmax(train_generator[0][1][idx])]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()
# CLASS_NAMES = ['Chickenpox','Measles','Monkeypoxg','Normal']

# %% [markdown]
# ## **4. Training a InceptionResNetV2 Model**
#
#
# ### i. Create a InceptionResNetV2 Model

# %%
base_model = tf.keras.applications.ResNet152V2(
                     include_top=False,
                     weights='imagenet',
                     input_shape=(150,150,3),
                    classifier_activation="softmax"

                     )

base_model.trainable=True
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234553344/234545216 [==============================] - 7s 0us/step
# 234561536/234545216 [==============================] - 7s 0us/step

# %%
model = tf.keras.Sequential([
        base_model,  
        tf.keras.layers.BatchNormalization(renorm=True),
        tf.keras.layers.GlobalAveragePooling2D(),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(4, activation='softmax')
    ])

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet152v2 (Functional)    (None, 5, 5, 2048)        58331648
#
#  batch_normalization (BatchN  (None, 5, 5, 2048)       14336
#  ormalization)
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 512)               1049088
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dense_3 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 59,559,812
# Trainable params: 59,405,828
# Non-trainable params: 153,984
# _________________________________________________________________
# None

# %% [markdown]
# ### ii. Defining Callbacks
# A callback is an object that can perform actions at various stages of training (e.g. at the start or end of an epoch, before or after a single batch, etc)
#
# a. Reduce Learning Rate on Plateau
# Is used to reduce the learning rate when a metric has stopped improving.

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)
early = tf.keras.callbacks.EarlyStopping( patience=10,
                                          min_delta=0.001,
                                          restore_best_weights=True)

# %% [markdown]
# ### iii. Defining the Optimizer

# %%
optimizer = Adam(learning_rate=0.001)
# !pip install tensorflow_addons
import tensorflow_addons as tfa
METRICS = [
      # tf.keras.metrics.BinaryAccuracy(name='binary_accuracy'),
      # tf.keras.metrics.Accuracy(name='accuracy'),
      tf.keras.metrics.CategoricalAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
      # tf.keras.metrics.F1Score(name='F1'),
      tfa.metrics.F1Score(num_classes= 4,name="f1_Score")

    
]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.18.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 34.6 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (21.3)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow_addons) (3.0.9)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.18.0

# %% [markdown]
# ### iv. Compile the Model

# %%
# cnn_model.compile(optimizer=optimizer, loss=CategoricalCrossentropy(), metrics=['accuracy'])
model.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=METRICS)

# %% [markdown]
# ### v. Training the Model

# %%
history = model.fit(train_generator,
                    steps_per_epoch=10,
                    validation_data=validation_generator,
                    validation_steps=2,
                    epochs=50,verbose = 2,
                    callbacks=[reduce_lr])
# Out:
# Epoch 1/50
# 10/10 - 210s - loss: 1.1552 - accuracy: 0.5363 - precision: 0.6706 - recall: 0.3596 - auc: 0.7715 - f1_Score: 0.4322 - val_loss: 705.3154 - val_accuracy: 0.2812 - val_precision: 0.2812 - val_recall: 0.2812 - val_auc: 0.5208 - val_f1_Score: 0.1098 - lr: 0.0010 - 210s/epoch - 21s/step
# Epoch 2/50
# 10/10 - 79s - loss: 1.3178 - accuracy: 0.5741 - precision: 0.6826 - recall: 0.3596 - auc: 0.8009 - f1_Score: 0.4754 - val_loss: 4109.1284 - val_accuracy: 0.3125 - val_precision: 0.3125 - val_recall: 0.3125 - val_auc: 0.5381 - val_f1_Score: 0.1190 - lr: 0.0010 - 79s/epoch - 8s/step
# Epoch 3/50
# 10/10 - 50s - loss: 1.0512 - accuracy: 0.5678 - precision: 0.7345 - recall: 0.4101 - auc: 0.8136 - f1_Score: 0.3666 - val_loss: 118041.3438 - val_accuracy: 0.3438 - val_precision: 0.3438 - val_recall: 0.3438 - val_auc: 0.5625 - val_f1_Score: 0.1279 - lr: 0.0010 - 50s/epoch - 5s/step
# Epoch 4/50
# 10/10 - 19s - loss: 0.9998 - accuracy: 0.6088 - precision: 0.7267 - recall: 0.3943 - auc: 0.8252 - f1_Score: 0.4855 - val_loss: 64446.1094 - val_accuracy: 0.3281 - val_precision: 0.3281 - val_recall: 0.3281 - val_auc: 0.5521 - val_f1_Score: 0.1235 - lr: 0.0010 - 19s/epoch - 2s/step
# Epoch 5/50
# 10/10 - 12s - loss: 1.3350 - accuracy: 0.5457 - precision: 0.6129 - recall: 0.3596 - auc: 0.7666 - f1_Score: 0.3902 - val_loss: 74756980736.0000 - val_accuracy: 0.3906 - val_precision: 0.3906 - val_recall: 0.3906 - val_auc: 0.5938 - val_f1_Score: 0.1404 - lr: 0.0010 - 12s/epoch - 1s/step
# Epoch 6/50
# 10/10 - 10s - loss: 1.2293 - accuracy: 0.4625 - precision: 0.5435 - recall: 0.1562 - auc: 0.7148 - f1_Score: 0.3345 - val_loss: 6720563707904.0000 - val_accuracy: 0.3750 - val_precision: 0.3750 - val_recall: 0.3750 - val_auc: 0.5833 - val_f1_Score: 0.1364 - lr: 0.0010 - 10s/epoch - 953ms/step
# Epoch 7/50
# 10/10 - 8s - loss: 1.2449 - accuracy: 0.5142 - precision: 0.7216 - recall: 0.2208 - auc: 0.7338 - f1_Score: 0.3514 - val_loss: 1517084928.0000 - val_accuracy: 0.3594 - val_precision: 0.3594 - val_recall: 0.3594 - val_auc: 0.5729 - val_f1_Score: 0.1322 - lr: 3.1623e-04 - 8s/epoch - 799ms/step
# Epoch 8/50
# 10/10 - 6s - loss: 1.1234 - accuracy: 0.5469 - precision: 0.7396 - recall: 0.2219 - auc: 0.7660 - f1_Score: 0.3480 - val_loss: 2853891.2500 - val_accuracy: 0.3750 - val_precision: 0.3750 - val_recall: 0.3750 - val_auc: 0.5833 - val_f1_Score: 0.1364 - lr: 3.1623e-04 - 6s/epoch - 600ms/step
# Epoch 9/50
# 10/10 - 6s - loss: 1.1688 - accuracy: 0.4844 - precision: 0.7872 - recall: 0.2313 - auc: 0.7470 - f1_Score: 0.3029 - val_loss: 29997.4414 - val_accuracy: 0.3438 - val_precision: 0.3438 - val_recall: 0.3438 - val_auc: 0.5625 - val_f1_Score: 0.1279 - lr: 3.1623e-04 - 6s/epoch - 584ms/step
# Epoch 10/50
# 10/10 - 7s - loss: 1.0297 - accuracy: 0.5836 - precision: 0.7188 - recall: 0.3628 - auc: 0.8163 - f1_Score: 0.3883 - val_loss: 1259.7784 - val_accuracy: 0.3281 - val_precision: 0.3281 - val_recall: 0.3281 - val_auc: 0.5521 - val_f1_Score: 0.1235 - lr: 3.1623e-04 - 7s/epoch - 656ms/step
# Epoch 11/50
# 10/10 - 5s - loss: 1.0018 - accuracy: 0.6057 - precision: 0.7255 - recall: 0.4669 - auc: 0.8248 - f1_Score: 0.3947 - val_loss: 208.3384 - val_accuracy: 0.3906 - val_precision: 0.3906 - val_recall: 0.3906 - val_auc: 0.6240 - val_f1_Score: 0.2030 - lr: 3.1623e-04 - 5s/epoch - 529ms/step
# Epoch 12/50
# 10/10 - 6s - loss: 0.9507 - accuracy: 0.6250 - precision: 0.7294 - recall: 0.4969 - auc: 0.8412 - f1_Score: 0.4230 - val_loss: 39.6491 - val_accuracy: 0.3906 - val_precision: 0.3906 - val_recall: 0.3906 - val_auc: 0.6572 - val_f1_Score: 0.2189 - lr: 3.1623e-04 - 6s/epoch - 585ms/step
# Epoch 13/50
# 10/10 - 5s - loss: 0.8947 - accuracy: 0.6906 - precision: 0.8137 - recall: 0.5188 - auc: 0.8658 - f1_Score: 0.5271 - val_loss: 25.7333 - val_accuracy: 0.5000 - val_precision: 0.4921 - val_recall: 0.4844 - val_auc: 0.6908 - val_f1_Score: 0.2728 - lr: 3.1623e-04 - 5s/epoch - 469ms/step
# Epoch 14/50
# 10/10 - 5s - loss: 0.9421 - accuracy: 0.6309 - precision: 0.7623 - recall: 0.5363 - auc: 0.8447 - f1_Score: 0.5081 - val_loss: 17.3737 - val_accuracy: 0.4219 - val_precision: 0.4219 - val_recall: 0.4219 - val_auc: 0.6260 - val_f1_Score: 0.2819 - lr: 3.1623e-04 - 5s/epoch - 459ms/step
# Epoch 15/50
# 10/10 - 5s - loss: 0.9327 - accuracy: 0.6372 - precision: 0.7880 - recall: 0.5394 - auc: 0.8514 - f1_Score: 0.4826 - val_loss: 10.6921 - val_accuracy: 0.4844 - val_precision: 0.4754 - val_recall: 0.4531 - val_auc: 0.6942 - val_f1_Score: 0.3052 - lr: 3.1623e-04 - 5s/epoch - 515ms/step
# Epoch 16/50
# 10/10 - 5s - loss: 0.8704 - accuracy: 0.6656 - precision: 0.8081 - recall: 0.5000 - auc: 0.8729 - f1_Score: 0.5600 - val_loss: 5.1776 - val_accuracy: 0.5781 - val_precision: 0.6034 - val_recall: 0.5469 - val_auc: 0.7343 - val_f1_Score: 0.4490 - lr: 3.1623e-04 - 5s/epoch - 472ms/step
# Epoch 17/50
# 10/10 - 5s - loss: 0.7939 - accuracy: 0.7066 - precision: 0.7897 - recall: 0.5804 - auc: 0.8937 - f1_Score: 0.6060 - val_loss: 1.4878 - val_accuracy: 0.5469 - val_precision: 0.6512 - val_recall: 0.4375 - val_auc: 0.7432 - val_f1_Score: 0.3703 - lr: 3.1623e-04 - 5s/epoch - 460ms/step
# Epoch 18/50
# 10/10 - 5s - loss: 0.8343 - accuracy: 0.7035 - precision: 0.8017 - recall: 0.5994 - auc: 0.8871 - f1_Score: 0.6146 - val_loss: 2.6896 - val_accuracy: 0.3750 - val_precision: 0.3729 - val_recall: 0.3438 - val_auc: 0.5763 - val_f1_Score: 0.2876 - lr: 3.1623e-04 - 5s/epoch - 462ms/step
# Epoch 19/50
# 10/10 - 5s - loss: 0.8454 - accuracy: 0.7224 - precision: 0.7951 - recall: 0.6120 - auc: 0.8841 - f1_Score: 0.6051 - val_loss: 4.6014 - val_accuracy: 0.3125 - val_precision: 0.4483 - val_recall: 0.2031 - val_auc: 0.6209 - val_f1_Score: 0.2714 - lr: 3.1623e-04 - 5s/epoch - 462ms/step
# Epoch 20/50
# 10/10 - 5s - loss: 0.7760 - accuracy: 0.7098 - precision: 0.7869 - recall: 0.6057 - auc: 0.8965 - f1_Score: 0.6394 - val_loss: 1.7854 - val_accuracy: 0.5156 - val_precision: 0.5741 - val_recall: 0.4844 - val_auc: 0.7599 - val_f1_Score: 0.4288 - lr: 3.1623e-04 - 5s/epoch - 463ms/step
# Epoch 21/50
# 10/10 - 5s - loss: 0.7732 - accuracy: 0.7287 - precision: 0.8143 - recall: 0.6088 - auc: 0.8988 - f1_Score: 0.6657 - val_loss: 0.9340 - val_accuracy: 0.6719 - val_precision: 0.6786 - val_recall: 0.5938 - val_auc: 0.8845 - val_f1_Score: 0.5572 - lr: 3.1623e-04 - 5s/epoch - 463ms/step
# Epoch 22/50
# 10/10 - 5s - loss: 0.6861 - accuracy: 0.7729 - precision: 0.8281 - recall: 0.6688 - auc: 0.9190 - f1_Score: 0.6896 - val_loss: 0.8444 - val_accuracy: 0.5938 - val_precision: 0.6863 - val_recall: 0.5469 - val_auc: 0.8762 - val_f1_Score: 0.3988 - lr: 3.1623e-04 - 5s/epoch - 466ms/step
# Epoch 23/50
# 10/10 - 5s - loss: 0.7034 - accuracy: 0.7375 - precision: 0.7956 - recall: 0.6812 - auc: 0.9150 - f1_Score: 0.6555 - val_loss: 0.8888 - val_accuracy: 0.6562 - val_precision: 0.7619 - val_recall: 0.5000 - val_auc: 0.8666 - val_f1_Score: 0.4694 - lr: 3.1623e-04 - 5s/epoch - 468ms/step
# Epoch 24/50
# 10/10 - 5s - loss: 0.6357 - accuracy: 0.7792 - precision: 0.8358 - recall: 0.7066 - auc: 0.9310 - f1_Score: 0.6663 - val_loss: 1.4131 - val_accuracy: 0.4688 - val_precision: 0.5185 - val_recall: 0.4375 - val_auc: 0.7228 - val_f1_Score: 0.2926 - lr: 3.1623e-04 - 5s/epoch - 465ms/step
# Epoch 25/50
# 10/10 - 5s - loss: 0.6588 - accuracy: 0.7594 - precision: 0.8377 - recall: 0.6938 - auc: 0.9271 - f1_Score: 0.6591 - val_loss: 1.6120 - val_accuracy: 0.4531 - val_precision: 0.4655 - val_recall: 0.4219 - val_auc: 0.7150 - val_f1_Score: 0.3829 - lr: 3.1623e-04 - 5s/epoch - 467ms/step
# Epoch 26/50
# 10/10 - 5s - loss: 0.5973 - accuracy: 0.8156 - precision: 0.8741 - recall: 0.7375 - auc: 0.9393 - f1_Score: 0.7615 - val_loss: 1.1732 - val_accuracy: 0.5781 - val_precision: 0.5741 - val_recall: 0.4844 - val_auc: 0.7743 - val_f1_Score: 0.4829 - lr: 3.1623e-04 - 5s/epoch - 470ms/step
# Epoch 27/50
# 10/10 - 5s - loss: 0.6769 - accuracy: 0.7625 - precision: 0.8014 - recall: 0.6938 - auc: 0.9224 - f1_Score: 0.6839 - val_loss: 1.2128 - val_accuracy: 0.5312 - val_precision: 0.5556 - val_recall: 0.4688 - val_auc: 0.7639 - val_f1_Score: 0.3164 - lr: 3.1623e-04 - 5s/epoch - 469ms/step
# Epoch 28/50
# 10/10 - 5s - loss: 0.6620 - accuracy: 0.7634 - precision: 0.8282 - recall: 0.6845 - auc: 0.9270 - f1_Score: 0.6801 - val_loss: 1.1140 - val_accuracy: 0.5469 - val_precision: 0.7027 - val_recall: 0.4062 - val_auc: 0.7806 - val_f1_Score: 0.3523 - lr: 1.0000e-04 - 5s/epoch - 468ms/step
# Epoch 29/50
# 10/10 - 5s - loss: 0.4913 - accuracy: 0.8328 - precision: 0.9030 - recall: 0.7634 - auc: 0.9605 - f1_Score: 0.7739 - val_loss: 0.9416 - val_accuracy: 0.6875 - val_precision: 0.8085 - val_recall: 0.5938 - val_auc: 0.8517 - val_f1_Score: 0.5554 - lr: 1.0000e-04 - 5s/epoch - 465ms/step
# Epoch 30/50
# 10/10 - 5s - loss: 0.4713 - accuracy: 0.8107 - precision: 0.8824 - recall: 0.7571 - auc: 0.9655 - f1_Score: 0.7533 - val_loss: 1.0860 - val_accuracy: 0.5781 - val_precision: 0.6731 - val_recall: 0.5469 - val_auc: 0.8317 - val_f1_Score: 0.3703 - lr: 1.0000e-04 - 5s/epoch - 469ms/step
# Epoch 31/50
# 10/10 - 5s - loss: 0.3895 - accuracy: 0.8719 - precision: 0.9203 - recall: 0.7937 - auc: 0.9780 - f1_Score: 0.8267 - val_loss: 0.8835 - val_accuracy: 0.6875 - val_precision: 0.6935 - val_recall: 0.6719 - val_auc: 0.8810 - val_f1_Score: 0.3950 - lr: 1.0000e-04 - 5s/epoch - 471ms/step
# Epoch 32/50
# 10/10 - 5s - loss: 0.4340 - accuracy: 0.8500 - precision: 0.8908 - recall: 0.8156 - auc: 0.9678 - f1_Score: 0.7965 - val_loss: 1.1993 - val_accuracy: 0.5938 - val_precision: 0.6102 - val_recall: 0.5625 - val_auc: 0.8060 - val_f1_Score: 0.3587 - lr: 1.0000e-04 - 5s/epoch - 472ms/step
# Epoch 33/50
# 10/10 - 5s - loss: 0.4203 - accuracy: 0.8517 - precision: 0.8962 - recall: 0.8170 - auc: 0.9689 - f1_Score: 0.8113 - val_loss: 0.7847 - val_accuracy: 0.6719 - val_precision: 0.7049 - val_recall: 0.6719 - val_auc: 0.9143 - val_f1_Score: 0.3835 - lr: 3.1623e-05 - 5s/epoch - 468ms/step
# Epoch 34/50
# 10/10 - 5s - loss: 0.3808 - accuracy: 0.8375 - precision: 0.8822 - recall: 0.8188 - auc: 0.9763 - f1_Score: 0.7760 - val_loss: 1.1931 - val_accuracy: 0.5938 - val_precision: 0.6333 - val_recall: 0.5938 - val_auc: 0.8382 - val_f1_Score: 0.3573 - lr: 3.1623e-05 - 5s/epoch - 471ms/step
# Epoch 35/50
# 10/10 - 5s - loss: 0.3596 - accuracy: 0.8644 - precision: 0.9138 - recall: 0.8360 - auc: 0.9778 - f1_Score: 0.8125 - val_loss: 1.0202 - val_accuracy: 0.6875 - val_precision: 0.6885 - val_recall: 0.6562 - val_auc: 0.8737 - val_f1_Score: 0.4040 - lr: 3.1623e-05 - 5s/epoch - 469ms/step
# Epoch 36/50
# 10/10 - 5s - loss: 0.3524 - accuracy: 0.8927 - precision: 0.9119 - recall: 0.8486 - auc: 0.9777 - f1_Score: 0.8655 - val_loss: 0.8910 - val_accuracy: 0.6875 - val_precision: 0.6984 - val_recall: 0.6875 - val_auc: 0.8910 - val_f1_Score: 0.4776 - lr: 3.1623e-05 - 5s/epoch - 467ms/step
# Epoch 37/50
# 10/10 - 5s - loss: 0.3163 - accuracy: 0.8959 - precision: 0.9283 - recall: 0.8580 - auc: 0.9836 - f1_Score: 0.8498 - val_loss: 1.0407 - val_accuracy: 0.6250 - val_precision: 0.6500 - val_recall: 0.6094 - val_auc: 0.8658 - val_f1_Score: 0.4459 - lr: 3.1623e-05 - 5s/epoch - 468ms/step
# Epoch 38/50
# 10/10 - 5s - loss: 0.3516 - accuracy: 0.8656 - precision: 0.9014 - recall: 0.8281 - auc: 0.9781 - f1_Score: 0.8111 - val_loss: 1.0491 - val_accuracy: 0.6406 - val_precision: 0.6667 - val_recall: 0.6250 - val_auc: 0.8767 - val_f1_Score: 0.4670 - lr: 3.1623e-05 - 5s/epoch - 530ms/step
# Epoch 39/50
# 10/10 - 5s - loss: 0.2926 - accuracy: 0.9000 - precision: 0.9418 - recall: 0.8594 - auc: 0.9863 - f1_Score: 0.8552 - val_loss: 0.7504 - val_accuracy: 0.7344 - val_precision: 0.7667 - val_recall: 0.7188 - val_auc: 0.9186 - val_f1_Score: 0.5992 - lr: 1.0000e-05 - 5s/epoch - 470ms/step
# Epoch 40/50
# 10/10 - 5s - loss: 0.3816 - accuracy: 0.8770 - precision: 0.9186 - recall: 0.8549 - auc: 0.9738 - f1_Score: 0.8405 - val_loss: 1.1982 - val_accuracy: 0.5938 - val_precision: 0.5968 - val_recall: 0.5781 - val_auc: 0.8402 - val_f1_Score: 0.4645 - lr: 1.0000e-05 - 5s/epoch - 468ms/step
# Epoch 41/50
# 10/10 - 5s - loss: 0.3428 - accuracy: 0.8896 - precision: 0.9195 - recall: 0.8644 - auc: 0.9779 - f1_Score: 0.8476 - val_loss: 0.6590 - val_accuracy: 0.7344 - val_precision: 0.7541 - val_recall: 0.7188 - val_auc: 0.9333 - val_f1_Score: 0.6606 - lr: 1.0000e-05 - 5s/epoch - 469ms/step
# Epoch 42/50
# 10/10 - 5s - loss: 0.3397 - accuracy: 0.8896 - precision: 0.9094 - recall: 0.8549 - auc: 0.9798 - f1_Score: 0.8583 - val_loss: 0.8213 - val_accuracy: 0.6875 - val_precision: 0.7458 - val_recall: 0.6875 - val_auc: 0.9024 - val_f1_Score: 0.5250 - lr: 1.0000e-05 - 5s/epoch - 470ms/step
# Epoch 43/50
# 10/10 - 5s - loss: 0.3241 - accuracy: 0.8675 - precision: 0.9147 - recall: 0.8454 - auc: 0.9833 - f1_Score: 0.8174 - val_loss: 0.7765 - val_accuracy: 0.6875 - val_precision: 0.7544 - val_recall: 0.6719 - val_auc: 0.9148 - val_f1_Score: 0.5760 - lr: 1.0000e-05 - 5s/epoch - 470ms/step
# Epoch 44/50
# 10/10 - 5s - loss: 0.3441 - accuracy: 0.8781 - precision: 0.9054 - recall: 0.8375 - auc: 0.9781 - f1_Score: 0.8289 - val_loss: 0.8306 - val_accuracy: 0.7500 - val_precision: 0.8070 - val_recall: 0.7188 - val_auc: 0.8985 - val_f1_Score: 0.6546 - lr: 1.0000e-05 - 5s/epoch - 473ms/step
# Epoch 45/50
# 10/10 - 5s - loss: 0.3409 - accuracy: 0.8938 - precision: 0.9203 - recall: 0.8656 - auc: 0.9782 - f1_Score: 0.8675 - val_loss: 0.8131 - val_accuracy: 0.7188 - val_precision: 0.7500 - val_recall: 0.7031 - val_auc: 0.9114 - val_f1_Score: 0.5791 - lr: 1.0000e-05 - 5s/epoch - 472ms/step
# Epoch 46/50
# 10/10 - 5s - loss: 0.3528 - accuracy: 0.8707 - precision: 0.9088 - recall: 0.8486 - auc: 0.9790 - f1_Score: 0.8196 - val_loss: 0.6684 - val_accuracy: 0.7188 - val_precision: 0.7759 - val_recall: 0.7031 - val_auc: 0.9295 - val_f1_Score: 0.5856 - lr: 1.0000e-05 - 5s/epoch - 469ms/step
# Epoch 47/50
# 10/10 - 5s - loss: 0.2683 - accuracy: 0.8991 - precision: 0.9418 - recall: 0.8675 - auc: 0.9911 - f1_Score: 0.8648 - val_loss: 0.8516 - val_accuracy: 0.7031 - val_precision: 0.7544 - val_recall: 0.6719 - val_auc: 0.8951 - val_f1_Score: 0.6258 - lr: 3.1623e-06 - 5s/epoch - 467ms/step
# Epoch 48/50
# 10/10 - 5s - loss: 0.2576 - accuracy: 0.9274 - precision: 0.9406 - recall: 0.8991 - auc: 0.9895 - f1_Score: 0.8959 - val_loss: 0.5654 - val_accuracy: 0.7812 - val_precision: 0.8333 - val_recall: 0.7812 - val_auc: 0.9526 - val_f1_Score: 0.6524 - lr: 3.1623e-06 - 5s/epoch - 470ms/step
# Epoch 49/50
# 10/10 - 5s - loss: 0.2843 - accuracy: 0.9211 - precision: 0.9365 - recall: 0.8833 - auc: 0.9855 - f1_Score: 0.8815 - val_loss: 0.6066 - val_accuracy: 0.7500 - val_precision: 0.7869 - val_recall: 0.7500 - val_auc: 0.9453 - val_f1_Score: 0.5659 - lr: 3.1623e-06 - 5s/epoch - 470ms/step
# Epoch 50/50
# 10/10 - 5s - loss: 0.3249 - accuracy: 0.8719 - precision: 0.9106 - recall: 0.8594 - auc: 0.9827 - f1_Score: 0.8319 - val_loss: 0.7233 - val_accuracy: 0.7344 - val_precision: 0.7833 - val_recall: 0.7344 - val_auc: 0.9319 - val_f1_Score: 0.6254 - lr: 3.1623e-06 - 5s/epoch - 473ms/step

# %% [markdown]
# ## **5. Plotting the Model Metrics**
# ### i. Plotting training and validation accuracy, loss and learning rate

# %%
plt.figure( figsize = (15,8)) 
    
plt.subplot(221)  
# Accuracy 
plt.plot(model.history.history['accuracy'])
plt.plot(model.history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training set', 'Validation set'], loc='upper left')
plt.show()


# Loss
plt.figure( figsize = (15,8)) 
plt.subplot(222)  
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training set', 'Validation set'], loc='upper left')
plt.show()

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

learning_rate = history.history['lr']

val_loss
# Out:
# [705.3153686523438,
#  4109.12841796875,
#  118041.34375,
#  64446.109375,
#  74756980736.0,
#  6720563707904.0,
#  1517084928.0,
#  2853891.25,
#  29997.44140625,
#  1259.7784423828125,
#  208.33843994140625,
#  39.64909362792969,
#  25.73330307006836,
#  17.37366485595703,
#  10.692121505737305,
#  5.177574157714844,
#  1.4878404140472412,
#  2.6896231174468994,
#  4.601424694061279,
#  1.7853542566299438,
#  0.9340199828147888,
#  0.8444081544876099,
#  0.8888194561004639,
#  1.4131274223327637,
#  1.6119685173034668,
#  1.1731855869293213,
#  1.2128491401672363,
#  1.1139569282531738,
#  0.9416370987892151,
#  1.0859590768814087,
#  0.8835391998291016,
#  1.1992554664611816,
#  0.7847490310668945,
#  1.1931229829788208,
#  1.0201880931854248,
#  0.890979528427124,
#  1.0406508445739746,
#  1.0491353273391724,
#  0.7503513693809509,
#  1.1981874704360962,
#  0.6589956283569336,
#  0.8212960958480835,
#  0.7765353918075562,
#  0.8305655121803284,
#  0.8130696415901184,
#  0.6683898568153381,
#  0.851597011089325,
#  0.565449595451355,
#  0.6066076159477234,
#  0.7233080863952637]

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %%
def Train_Val_Plot(acc,val_acc,loss,val_loss,auc,val_auc,precision,val_precision,f1_Score,val_f1_Score):
    
    fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])
    
    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('AUC')
    ax3.legend(['training', 'validation'])
    
    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Precision')
    ax4.legend(['training', 'validation'])
    
    ax5.plot(range(1, len(f1_Score) + 1), f1_Score)
    ax5.plot(range(1, len(val_f1_Score) + 1), val_f1_Score)
    ax5.set_title('History of F1-score')
    ax5.set_xlabel('Epochs')
    ax5.set_ylabel('F1 score')
    ax5.legend(['training', 'validation'])


    plt.show()
    
import numpy as np
# f1_s= np.mean(history.history['f1_Score'])
# val_f1_s= np.mean(history.history['val_f1_Score'])
Train_Val_Plot(history.history['accuracy'],history.history['val_accuracy'],
               history.history['loss'],history.history['val_loss'],
               history.history['auc'],history.history['val_auc'],
               history.history['precision'],history.history['val_precision']
              #  f1_s,val_f1_s

                , history.history['f1_Score'],history.history['val_f1_Score']
              )

# %% [markdown]
# ## 6. Testing the Model on Test Set
# Testing the model on the validation dataset because a seperate dataset for testing is not available.

# %%
test_dataset = '/content/drive/MyDrive/Monkeypox_Skin_Image_Dataset/Test'

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255)

test_generator = test_datagen.flow_from_directory(test_dataset,
                                                 shuffle=False,
                                                 batch_size=BATCH_SIZE,
                                                 target_size = (IMG_WIDTH, IMG_HEIGHT),
                                                 class_mode='categorical')
# Out:
# Found 241 images belonging to 4 classes.

# %% [markdown]
# ## 7. Model Prediction on the Test Dataset

# %%
predictions = model.predict(test_generator)

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        predicted_label = labels[np.argmax(predictions[idx])]
        ax[i, j].set_title(f"{predicted_label}")
        ax[i, j].imshow(test_generator[0][0][idx])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Test Dataset Predictions", fontsize=20)
plt.show()

# %%
train_loss, train_accuracy, train_precision, train_recall, train_auc, train_F1_Score = model.evaluate(train_generator, batch_size=BATCH_SIZE)
# Out:
# 17/17 [==============================] - 5s 273ms/step - loss: 0.3098 - accuracy: 0.8835 - precision: 0.9155 - recall: 0.8614 - auc: 0.9839 - f1_Score: 0.8339

# %%
print(f"Train Loss:     {train_loss*100}")
print(f"Train Accuracy: {train_accuracy*100}")
print(f"Train Precision: {train_precision*100}")
print(f"Train Recall: {train_recall*100}")
print(f"Train AUC: {train_auc*100}")
print(f"Train F1_Score: {np.mean(train_F1_Score)*100}")
# Out:
# Train Loss:     30.975762009620667
# Train Accuracy: 88.35489749908447
# Train Precision: 91.55206084251404
# Train Recall: 86.13678216934204
# Train AUC: 98.3874499797821
# Train F1_Score: 83.3910346031189

# %%
test_loss, test_accuracy, test_precision, test_recall, test_auc, test_F1_Score = model.evaluate(test_generator, batch_size=BATCH_SIZE)
# Out:
# 8/8 [==============================] - 1s 126ms/step - loss: 0.6186 - accuracy: 0.8008 - precision: 0.8333 - recall: 0.7676 - auc: 0.9403 - f1_Score: 0.7141

# %%
print(f"Test Loss:     {test_loss*100}")
print(f"Test Accuracy: {test_accuracy*100}")
print(f"Test Precision: {test_precision*100}")
print(f"Test Recall: {test_recall*100}")
print(f"Test AUC: {test_auc*100}")
print(f"Test F1_Score: {np.mean(test_F1_Score)*100}")
# Out:
# Test Loss:     61.86223030090332
# Test Accuracy: 80.08298873901367
# Test Precision: 83.33333134651184
# Test Recall: 76.76348686218262
# Test AUC: 94.02816891670227
# Test F1_Score: 71.40799164772034

# %% [markdown]
# ## **8. Plotting the Classification Metrics**
# ### i. Confusion Matrix

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# %%
cf_mtx = confusion_matrix(y_true, y_pred)

group_counts = ["{0:0.0f}".format(value) for value in cf_mtx.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_mtx.flatten()/np.sum(cf_mtx)]
box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
box_labels = np.asarray(box_labels).reshape(4, 4)

plt.figure(figsize = (12, 10))
sns.heatmap(cf_mtx, xticklabels=labels.values(), yticklabels=labels.values(),
           cmap="YlGnBu", fmt="", annot=box_labels)
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')
plt.show()

# %%
print(classification_report(y_true, y_pred, target_names=labels.values()))
# Out:
#               precision    recall  f1-score   support
#
#   Chickenpox       0.76      0.47      0.58        34
#      Measles       0.92      0.39      0.55        31
#    Monkeypox       0.71      0.93      0.81        87
#       Normal       0.90      0.94      0.92        89
#
#     accuracy                           0.80       241
#    macro avg       0.82      0.68      0.71       241
# weighted avg       0.82      0.80      0.78       241

# %% [markdown]
# ## **9. Wrong Predictions**
# Let's see where the model has given wrong predictions and what were the actual predictions on those images

# %%
errors = (y_true - y_pred != 0)
y_true_errors = y_true[errors]
y_pred_errors = y_pred[errors]

# %%
test_images = test_generator.filenames
test_img = np.asarray(test_images)[errors]

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        idx = np.random.randint(0, len(test_img))
        true_index = y_true_errors[idx]
        true_label = labels[true_index]
        predicted_index = y_pred_errors[idx]
        predicted_label = labels[predicted_index]
        ax[i, j].set_title(f"True Label: {true_label} \n Predicted Label: {predicted_label}")
        img_path = os.path.join(test_dataset, test_img[idx])
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        ax[i, j].imshow(img)
        ax[i, j].axis("off")

plt.tight_layout()
plt.suptitle('Wrong Predictions made on test set', fontsize=20)
plt.show()
