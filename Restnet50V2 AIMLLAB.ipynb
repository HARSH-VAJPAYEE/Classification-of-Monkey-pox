# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Importing necessary packages**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import PIL
# import tensorflow as tf
# from tensorflow.keras import layers,Dense,Flatten
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.optimizers import Adam

import cv2
import os
# os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPool2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# %% [markdown]
# ## **2. Load the Image Training and Validation Datasets**
#
# ### i. Get the Image Dataset Paths

# %%
train_dataset_path = '/content/drive/MyDrive/Monkeypox_Skin_Image_Dataset/Train'
validation_dataset_path = '/content/drive/MyDrive/Monkeypox_Skin_Image_Dataset/Test'

# %% [markdown]
# ### ii. Load Image Datasets and Apply Augmentations
# Since the images present in the datasets are 150x150px in size, the image height and width are taken as 150, 150 respectively. The batch size value can be changed if required.

# %%
img_height,img_width=150,150
batch_size=3

# %% [markdown]
# Loading the training dataset and applying augmentations on it.

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                  zoom_range=0.2,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  fill_mode='nearest')
train_generator = train_datagen.flow_from_directory(train_dataset_path,
                                                   target_size=(img_height,img_width),
                                                   batch_size=32,
                                                   class_mode='categorical',
                                                   shuffle=True)
# Out:
# Found 541 images belonging to 4 classes.

# %% [markdown]
# Loading the validation dataset.

# %%
validation_datagen = ImageDataGenerator(rescale=1.0/255)
validation_generator = validation_datagen.flow_from_directory(validation_dataset_path,
                                                             target_size=(img_width,img_height),
                                                             batch_size=32,
                                                             class_mode='categorical',
                                                             shuffle=True)
# Out:
# Found 241 images belonging to 4 classes.

# %% [markdown]
# ### iii. Get the Label Mappings
# The labels dictionary is made in order to retrive the class names against the label indices used for training the model

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : Chickenpox
# 1 : Measles
# 2 : Monkeypox
# 3 : Normal

# %% [markdown]
# ## **3. Plotting Sample Training Image**s

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx = 0

for i in range(2):
    for j in range(5):
        label = labels[np.argmax(train_generator[0][1][idx])]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()
CLASS_NAMES = ['Chickenpox','Measles','Monkeypoxg','Normal']

# %% [markdown]
# ## **4. Training a RestNet50 Model**
#
#
# ### i. Create a RestNEt50 Model

# %%
base_model = tf.keras.applications.ResNet50V2(
    include_top=False,
    weights="imagenet",
    classifier_activation="softmax"
)

base_model.trainable=True
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94674944/94668760 [==============================] - 1s 0us/step
# 94683136/94668760 [==============================] - 1s 0us/step

# %%
model = tf.keras.Sequential([
        base_model,  
        tf.keras.layers.BatchNormalization(renorm=True),
        tf.keras.layers.GlobalAveragePooling2D(),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(4, activation='softmax')
    ])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50v2 (Functional)     (None, None, None, 2048)  23564800
#
#  batch_normalization (BatchN  (None, None, None, 2048)  14336
#  ormalization)
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 512)               1049088
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dense_3 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 24,792,964
# Trainable params: 24,737,284
# Non-trainable params: 55,680
# _________________________________________________________________

# %% [markdown]
# ### ii. Defining Callbacks
# A callback is an object that can perform actions at various stages of training (e.g. at the start or end of an epoch, before or after a single batch, etc)
#
# a. Reduce Learning Rate on Plateau
# Is used to reduce the learning rate when a metric has stopped improving.

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)

# %% [markdown]
# ### iii. Defining the Optimizer

# %%
optimizer = Adam(learning_rate=0.001)

# %% [markdown]
# ### iv. Compile the Model

# %%
# !pip install tensorflow_addons
import tensorflow_addons as tfa
METRICS = [
      # tf.keras.metrics.BinaryAccuracy(name='binary_accuracy'),
      # tf.keras.metrics.Accuracy(name='accuracy'),
      tf.keras.metrics.CategoricalAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
      # tf.keras.metrics.F1Score(name='F1'),
      tfa.metrics.F1Score(num_classes= 4,name="f1_Score")

    
]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.18.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 6.6 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (21.3)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow_addons) (3.0.9)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.18.0

# %%
model.compile(optimizer=optimizer,loss = 'categorical_crossentropy', metrics=METRICS)

# %% [markdown]
# ### v. Training the Model

# %%
history =  model.fit(train_generator,
                    steps_per_epoch=10,
                    validation_data=validation_generator,
                    validation_steps=2,
                    epochs=50,verbose = 2,
                    callbacks=[reduce_lr])
# Out:
# Epoch 1/50
# 10/10 - 137s - loss: 1.2379 - accuracy: 0.5469 - precision: 0.7234 - recall: 0.3187 - auc: 0.7718 - f1_Score: 0.3382 - val_loss: 618.3221 - val_accuracy: 0.3438 - val_precision: 0.3438 - val_recall: 0.3438 - val_auc: 0.5625 - val_f1_Score: 0.1279 - lr: 0.0010 - 137s/epoch - 14s/step
# Epoch 2/50
# 10/10 - 55s - loss: 1.1334 - accuracy: 0.6088 - precision: 0.7208 - recall: 0.3502 - auc: 0.8073 - f1_Score: 0.3491 - val_loss: 266.9283 - val_accuracy: 0.4375 - val_precision: 0.4375 - val_recall: 0.4375 - val_auc: 0.6250 - val_f1_Score: 0.1522 - lr: 0.0010 - 55s/epoch - 5s/step
# Epoch 3/50
# 10/10 - 22s - loss: 0.9595 - accuracy: 0.6278 - precision: 0.7553 - recall: 0.4479 - auc: 0.8429 - f1_Score: 0.4425 - val_loss: 207.6615 - val_accuracy: 0.3438 - val_precision: 0.3438 - val_recall: 0.3438 - val_auc: 0.5625 - val_f1_Score: 0.1279 - lr: 0.0010 - 22s/epoch - 2s/step
# Epoch 4/50
# 10/10 - 14s - loss: 0.9440 - accuracy: 0.6593 - precision: 0.7731 - recall: 0.5268 - auc: 0.8636 - f1_Score: 0.4975 - val_loss: 99.6317 - val_accuracy: 0.3594 - val_precision: 0.3594 - val_recall: 0.3594 - val_auc: 0.5729 - val_f1_Score: 0.1322 - lr: 0.0010 - 14s/epoch - 1s/step
# Epoch 5/50
# 10/10 - 10s - loss: 0.9582 - accuracy: 0.6625 - precision: 0.7634 - recall: 0.5344 - auc: 0.8489 - f1_Score: 0.4677 - val_loss: 11223.7119 - val_accuracy: 0.3594 - val_precision: 0.3594 - val_recall: 0.3594 - val_auc: 0.5729 - val_f1_Score: 0.1322 - lr: 0.0010 - 10s/epoch - 973ms/step
# Epoch 6/50
# 10/10 - 5s - loss: 0.9212 - accuracy: 0.6404 - precision: 0.7395 - recall: 0.5016 - auc: 0.8529 - f1_Score: 0.4428 - val_loss: 2014.0759 - val_accuracy: 0.4219 - val_precision: 0.4219 - val_recall: 0.4219 - val_auc: 0.6146 - val_f1_Score: 0.1484 - lr: 0.0010 - 5s/epoch - 532ms/step
# Epoch 7/50
# 10/10 - 6s - loss: 0.8152 - accuracy: 0.6845 - precision: 0.7871 - recall: 0.6183 - auc: 0.8903 - f1_Score: 0.4931 - val_loss: 359.0273 - val_accuracy: 0.4531 - val_precision: 0.4531 - val_recall: 0.4531 - val_auc: 0.6354 - val_f1_Score: 0.1559 - lr: 0.0010 - 6s/epoch - 563ms/step
# Epoch 8/50
# 10/10 - 5s - loss: 0.8953 - accuracy: 0.6719 - precision: 0.7953 - recall: 0.5394 - auc: 0.8753 - f1_Score: 0.5574 - val_loss: 99.5221 - val_accuracy: 0.5312 - val_precision: 0.5517 - val_recall: 0.5000 - val_auc: 0.6956 - val_f1_Score: 0.3748 - lr: 0.0010 - 5s/epoch - 521ms/step
# Epoch 9/50
# 10/10 - 4s - loss: 0.6580 - accuracy: 0.7539 - precision: 0.8360 - recall: 0.6593 - auc: 0.9262 - f1_Score: 0.6502 - val_loss: 382.0920 - val_accuracy: 0.2656 - val_precision: 0.2656 - val_recall: 0.2656 - val_auc: 0.5160 - val_f1_Score: 0.1717 - lr: 0.0010 - 4s/epoch - 416ms/step
# Epoch 10/50
# 10/10 - 4s - loss: 0.6949 - accuracy: 0.7350 - precision: 0.8016 - recall: 0.6246 - auc: 0.9167 - f1_Score: 0.6901 - val_loss: 35.9119 - val_accuracy: 0.3594 - val_precision: 0.3710 - val_recall: 0.3594 - val_auc: 0.6292 - val_f1_Score: 0.2375 - lr: 0.0010 - 4s/epoch - 396ms/step
# Epoch 11/50
# 10/10 - 3s - loss: 0.7613 - accuracy: 0.7375 - precision: 0.8340 - recall: 0.6438 - auc: 0.9083 - f1_Score: 0.6494 - val_loss: 23.6098 - val_accuracy: 0.1406 - val_precision: 0.1270 - val_recall: 0.1250 - val_auc: 0.4106 - val_f1_Score: 0.1003 - lr: 0.0010 - 3s/epoch - 340ms/step
# Epoch 12/50
# 10/10 - 3s - loss: 0.7784 - accuracy: 0.7035 - precision: 0.7958 - recall: 0.6025 - auc: 0.8984 - f1_Score: 0.6103 - val_loss: 32.2988 - val_accuracy: 0.2969 - val_precision: 0.2969 - val_recall: 0.2969 - val_auc: 0.5497 - val_f1_Score: 0.1762 - lr: 0.0010 - 3s/epoch - 337ms/step
# Epoch 13/50
# 10/10 - 3s - loss: 0.7251 - accuracy: 0.7539 - precision: 0.8683 - recall: 0.6656 - auc: 0.9136 - f1_Score: 0.6703 - val_loss: 7.0058 - val_accuracy: 0.4219 - val_precision: 0.4262 - val_recall: 0.4062 - val_auc: 0.6430 - val_f1_Score: 0.3024 - lr: 0.0010 - 3s/epoch - 339ms/step
# Epoch 14/50
# 10/10 - 4s - loss: 0.7793 - accuracy: 0.7161 - precision: 0.7786 - recall: 0.6435 - auc: 0.8992 - f1_Score: 0.6082 - val_loss: 19.2141 - val_accuracy: 0.4375 - val_precision: 0.4375 - val_recall: 0.4375 - val_auc: 0.6447 - val_f1_Score: 0.2961 - lr: 0.0010 - 4s/epoch - 383ms/step
# Epoch 15/50
# 10/10 - 3s - loss: 0.6724 - accuracy: 0.7539 - precision: 0.8199 - recall: 0.6751 - auc: 0.9281 - f1_Score: 0.6745 - val_loss: 5.0829 - val_accuracy: 0.4531 - val_precision: 0.4444 - val_recall: 0.3750 - val_auc: 0.6535 - val_f1_Score: 0.3798 - lr: 0.0010 - 3s/epoch - 342ms/step
# Epoch 16/50
# 10/10 - 3s - loss: 0.6340 - accuracy: 0.7571 - precision: 0.8258 - recall: 0.6877 - auc: 0.9313 - f1_Score: 0.6598 - val_loss: 2.7450 - val_accuracy: 0.6406 - val_precision: 0.6441 - val_recall: 0.5938 - val_auc: 0.8092 - val_f1_Score: 0.5153 - lr: 0.0010 - 3s/epoch - 337ms/step
# Epoch 17/50
# 10/10 - 3s - loss: 0.6274 - accuracy: 0.8250 - precision: 0.8636 - recall: 0.7125 - auc: 0.9397 - f1_Score: 0.7977 - val_loss: 5.3040 - val_accuracy: 0.4062 - val_precision: 0.3871 - val_recall: 0.3750 - val_auc: 0.5345 - val_f1_Score: 0.2791 - lr: 0.0010 - 3s/epoch - 343ms/step
# Epoch 18/50
# 10/10 - 3s - loss: 0.7356 - accuracy: 0.7666 - precision: 0.7931 - recall: 0.7256 - auc: 0.9174 - f1_Score: 0.7023 - val_loss: 14.4055 - val_accuracy: 0.3438 - val_precision: 0.3438 - val_recall: 0.3438 - val_auc: 0.5544 - val_f1_Score: 0.2727 - lr: 0.0010 - 3s/epoch - 342ms/step
# Epoch 19/50
# 10/10 - 3s - loss: 0.6937 - accuracy: 0.7350 - precision: 0.8313 - recall: 0.6530 - auc: 0.9197 - f1_Score: 0.6159 - val_loss: 19.9500 - val_accuracy: 0.3594 - val_precision: 0.3770 - val_recall: 0.3594 - val_auc: 0.5887 - val_f1_Score: 0.1625 - lr: 0.0010 - 3s/epoch - 343ms/step
# Epoch 20/50
# 10/10 - 3s - loss: 0.5673 - accuracy: 0.8170 - precision: 0.8379 - recall: 0.7666 - auc: 0.9441 - f1_Score: 0.7748 - val_loss: 9.8165 - val_accuracy: 0.6406 - val_precision: 0.6452 - val_recall: 0.6250 - val_auc: 0.7654 - val_f1_Score: 0.4877 - lr: 0.0010 - 3s/epoch - 336ms/step
# Epoch 21/50
# 10/10 - 3s - loss: 0.5194 - accuracy: 0.8233 - precision: 0.8641 - recall: 0.7823 - auc: 0.9524 - f1_Score: 0.7847 - val_loss: 11.0866 - val_accuracy: 0.1875 - val_precision: 0.1875 - val_recall: 0.1875 - val_auc: 0.4289 - val_f1_Score: 0.1345 - lr: 0.0010 - 3s/epoch - 339ms/step
# Epoch 22/50
# 10/10 - 3s - loss: 0.5044 - accuracy: 0.8202 - precision: 0.8464 - recall: 0.7823 - auc: 0.9584 - f1_Score: 0.7632 - val_loss: 6.7200 - val_accuracy: 0.2969 - val_precision: 0.2969 - val_recall: 0.2969 - val_auc: 0.5321 - val_f1_Score: 0.2256 - lr: 3.1623e-04 - 3s/epoch - 345ms/step
# Epoch 23/50
# 10/10 - 3s - loss: 0.4415 - accuracy: 0.8233 - precision: 0.8768 - recall: 0.7855 - auc: 0.9678 - f1_Score: 0.7816 - val_loss: 3.3646 - val_accuracy: 0.5625 - val_precision: 0.5714 - val_recall: 0.5625 - val_auc: 0.7169 - val_f1_Score: 0.4235 - lr: 3.1623e-04 - 3s/epoch - 343ms/step
# Epoch 24/50
# 10/10 - 3s - loss: 0.3182 - accuracy: 0.8927 - precision: 0.9076 - recall: 0.8675 - auc: 0.9837 - f1_Score: 0.8477 - val_loss: 2.3162 - val_accuracy: 0.5312 - val_precision: 0.5246 - val_recall: 0.5000 - val_auc: 0.7314 - val_f1_Score: 0.4087 - lr: 3.1623e-04 - 3s/epoch - 343ms/step
# Epoch 25/50
# 10/10 - 3s - loss: 0.3818 - accuracy: 0.8813 - precision: 0.8882 - recall: 0.8438 - auc: 0.9737 - f1_Score: 0.8302 - val_loss: 1.7383 - val_accuracy: 0.5938 - val_precision: 0.6066 - val_recall: 0.5781 - val_auc: 0.7810 - val_f1_Score: 0.4405 - lr: 3.1623e-04 - 3s/epoch - 340ms/step
# Epoch 26/50
# 10/10 - 3s - loss: 0.3758 - accuracy: 0.8675 - precision: 0.8986 - recall: 0.8391 - auc: 0.9747 - f1_Score: 0.8219 - val_loss: 1.4108 - val_accuracy: 0.6562 - val_precision: 0.6667 - val_recall: 0.6250 - val_auc: 0.8276 - val_f1_Score: 0.5553 - lr: 3.1623e-04 - 3s/epoch - 335ms/step
# Epoch 27/50
# 10/10 - 3s - loss: 0.2762 - accuracy: 0.9180 - precision: 0.9418 - recall: 0.8675 - auc: 0.9875 - f1_Score: 0.8900 - val_loss: 0.7533 - val_accuracy: 0.7812 - val_precision: 0.7903 - val_recall: 0.7656 - val_auc: 0.9214 - val_f1_Score: 0.7209 - lr: 3.1623e-04 - 3s/epoch - 338ms/step
# Epoch 28/50
# 10/10 - 3s - loss: 0.2821 - accuracy: 0.9031 - precision: 0.9161 - recall: 0.8875 - auc: 0.9855 - f1_Score: 0.8753 - val_loss: 0.7973 - val_accuracy: 0.7656 - val_precision: 0.7833 - val_recall: 0.7344 - val_auc: 0.9192 - val_f1_Score: 0.7524 - lr: 3.1623e-04 - 3s/epoch - 346ms/step
# Epoch 29/50
# 10/10 - 3s - loss: 0.2827 - accuracy: 0.8864 - precision: 0.9085 - recall: 0.8770 - auc: 0.9847 - f1_Score: 0.8560 - val_loss: 1.8160 - val_accuracy: 0.5781 - val_precision: 0.5968 - val_recall: 0.5781 - val_auc: 0.7940 - val_f1_Score: 0.4186 - lr: 3.1623e-04 - 3s/epoch - 344ms/step
# Epoch 30/50
# 10/10 - 3s - loss: 0.3269 - accuracy: 0.9054 - precision: 0.9238 - recall: 0.8801 - auc: 0.9802 - f1_Score: 0.8706 - val_loss: 1.5552 - val_accuracy: 0.6094 - val_precision: 0.6190 - val_recall: 0.6094 - val_auc: 0.8569 - val_f1_Score: 0.4797 - lr: 3.1623e-04 - 3s/epoch - 343ms/step
# Epoch 31/50
# 10/10 - 3s - loss: 0.2563 - accuracy: 0.9054 - precision: 0.9300 - recall: 0.8801 - auc: 0.9878 - f1_Score: 0.8597 - val_loss: 2.1073 - val_accuracy: 0.5781 - val_precision: 0.5968 - val_recall: 0.5781 - val_auc: 0.7580 - val_f1_Score: 0.4380 - lr: 3.1623e-04 - 3s/epoch - 344ms/step
# Epoch 32/50
# 10/10 - 4s - loss: 0.2374 - accuracy: 0.9094 - precision: 0.9373 - recall: 0.8875 - auc: 0.9906 - f1_Score: 0.8877 - val_loss: 2.8671 - val_accuracy: 0.5156 - val_precision: 0.5161 - val_recall: 0.5000 - val_auc: 0.7332 - val_f1_Score: 0.3963 - lr: 3.1623e-04 - 4s/epoch - 390ms/step
# Epoch 33/50
# 10/10 - 4s - loss: 0.2499 - accuracy: 0.9211 - precision: 0.9256 - recall: 0.9022 - auc: 0.9863 - f1_Score: 0.8961 - val_loss: 1.5448 - val_accuracy: 0.6562 - val_precision: 0.6721 - val_recall: 0.6406 - val_auc: 0.8477 - val_f1_Score: 0.5412 - lr: 1.0000e-04 - 4s/epoch - 352ms/step
# Epoch 34/50
# 10/10 - 3s - loss: 0.1580 - accuracy: 0.9432 - precision: 0.9674 - recall: 0.9369 - auc: 0.9956 - f1_Score: 0.9205 - val_loss: 0.9132 - val_accuracy: 0.7969 - val_precision: 0.8065 - val_recall: 0.7812 - val_auc: 0.9148 - val_f1_Score: 0.7358 - lr: 1.0000e-04 - 3s/epoch - 337ms/step
# Epoch 35/50
# 10/10 - 3s - loss: 0.1265 - accuracy: 0.9621 - precision: 0.9741 - recall: 0.9495 - auc: 0.9974 - f1_Score: 0.9553 - val_loss: 0.9738 - val_accuracy: 0.7500 - val_precision: 0.7460 - val_recall: 0.7344 - val_auc: 0.8927 - val_f1_Score: 0.6237 - lr: 1.0000e-04 - 3s/epoch - 340ms/step
# Epoch 36/50
# 10/10 - 3s - loss: 0.1584 - accuracy: 0.9469 - precision: 0.9587 - recall: 0.9438 - auc: 0.9960 - f1_Score: 0.9284 - val_loss: 0.9961 - val_accuracy: 0.7500 - val_precision: 0.7619 - val_recall: 0.7500 - val_auc: 0.8923 - val_f1_Score: 0.6400 - lr: 1.0000e-04 - 3s/epoch - 342ms/step
# Epoch 37/50
# 10/10 - 3s - loss: 0.1381 - accuracy: 0.9590 - precision: 0.9678 - recall: 0.9495 - auc: 0.9962 - f1_Score: 0.9464 - val_loss: 0.7272 - val_accuracy: 0.8125 - val_precision: 0.8254 - val_recall: 0.8125 - val_auc: 0.9250 - val_f1_Score: 0.7408 - lr: 1.0000e-04 - 3s/epoch - 340ms/step
# Epoch 38/50
# 10/10 - 3s - loss: 0.1419 - accuracy: 0.9656 - precision: 0.9744 - recall: 0.9500 - auc: 0.9950 - f1_Score: 0.9548 - val_loss: 1.0911 - val_accuracy: 0.6875 - val_precision: 0.7213 - val_recall: 0.6875 - val_auc: 0.8887 - val_f1_Score: 0.6320 - lr: 1.0000e-04 - 3s/epoch - 342ms/step
# Epoch 39/50
# 10/10 - 3s - loss: 0.1333 - accuracy: 0.9621 - precision: 0.9709 - recall: 0.9464 - auc: 0.9968 - f1_Score: 0.9495 - val_loss: 1.1282 - val_accuracy: 0.7500 - val_precision: 0.7541 - val_recall: 0.7188 - val_auc: 0.8805 - val_f1_Score: 0.6439 - lr: 1.0000e-04 - 3s/epoch - 337ms/step
# Epoch 40/50
# 10/10 - 3s - loss: 0.1193 - accuracy: 0.9656 - precision: 0.9654 - recall: 0.9594 - auc: 0.9975 - f1_Score: 0.9496 - val_loss: 0.8936 - val_accuracy: 0.7344 - val_precision: 0.7586 - val_recall: 0.6875 - val_auc: 0.8964 - val_f1_Score: 0.7286 - lr: 1.0000e-04 - 3s/epoch - 344ms/step
# Epoch 41/50
# 10/10 - 3s - loss: 0.0839 - accuracy: 0.9779 - precision: 0.9808 - recall: 0.9653 - auc: 0.9990 - f1_Score: 0.9672 - val_loss: 1.0177 - val_accuracy: 0.7500 - val_precision: 0.7419 - val_recall: 0.7188 - val_auc: 0.9037 - val_f1_Score: 0.6964 - lr: 1.0000e-04 - 3s/epoch - 344ms/step
# Epoch 42/50
# 10/10 - 3s - loss: 0.1356 - accuracy: 0.9495 - precision: 0.9524 - recall: 0.9464 - auc: 0.9964 - f1_Score: 0.9375 - val_loss: 0.7045 - val_accuracy: 0.7812 - val_precision: 0.8421 - val_recall: 0.7500 - val_auc: 0.9368 - val_f1_Score: 0.6724 - lr: 1.0000e-04 - 3s/epoch - 339ms/step
# Epoch 43/50
# 10/10 - 3s - loss: 0.1209 - accuracy: 0.9653 - precision: 0.9774 - recall: 0.9558 - auc: 0.9972 - f1_Score: 0.9464 - val_loss: 1.0734 - val_accuracy: 0.6719 - val_precision: 0.7049 - val_recall: 0.6719 - val_auc: 0.8858 - val_f1_Score: 0.5284 - lr: 1.0000e-04 - 3s/epoch - 341ms/step
# Epoch 44/50
# 10/10 - 3s - loss: 0.1154 - accuracy: 0.9656 - precision: 0.9687 - recall: 0.9656 - auc: 0.9977 - f1_Score: 0.9509 - val_loss: 0.7668 - val_accuracy: 0.7656 - val_precision: 0.7619 - val_recall: 0.7500 - val_auc: 0.9214 - val_f1_Score: 0.7399 - lr: 1.0000e-04 - 3s/epoch - 348ms/step
# Epoch 45/50
# 10/10 - 3s - loss: 0.0938 - accuracy: 0.9688 - precision: 0.9747 - recall: 0.9625 - auc: 0.9984 - f1_Score: 0.9627 - val_loss: 0.7067 - val_accuracy: 0.7812 - val_precision: 0.7937 - val_recall: 0.7812 - val_auc: 0.9432 - val_f1_Score: 0.6772 - lr: 1.0000e-04 - 3s/epoch - 345ms/step
# Epoch 46/50
# 10/10 - 3s - loss: 0.1469 - accuracy: 0.9432 - precision: 0.9462 - recall: 0.9432 - auc: 0.9949 - f1_Score: 0.9130 - val_loss: 0.5089 - val_accuracy: 0.7812 - val_precision: 0.8065 - val_recall: 0.7812 - val_auc: 0.9569 - val_f1_Score: 0.7125 - lr: 1.0000e-04 - 3s/epoch - 340ms/step
# Epoch 47/50
# 10/10 - 3s - loss: 0.0771 - accuracy: 0.9748 - precision: 0.9840 - recall: 0.9716 - auc: 0.9994 - f1_Score: 0.9649 - val_loss: 0.8142 - val_accuracy: 0.7656 - val_precision: 0.7742 - val_recall: 0.7500 - val_auc: 0.9351 - val_f1_Score: 0.7239 - lr: 1.0000e-04 - 3s/epoch - 336ms/step
# Epoch 48/50
# 10/10 - 3s - loss: 0.0966 - accuracy: 0.9716 - precision: 0.9808 - recall: 0.9653 - auc: 0.9986 - f1_Score: 0.9600 - val_loss: 0.4895 - val_accuracy: 0.8438 - val_precision: 0.8413 - val_recall: 0.8281 - val_auc: 0.9651 - val_f1_Score: 0.7969 - lr: 1.0000e-04 - 3s/epoch - 341ms/step
# Epoch 49/50
# 10/10 - 3s - loss: 0.1621 - accuracy: 0.9590 - precision: 0.9651 - recall: 0.9590 - auc: 0.9917 - f1_Score: 0.9447 - val_loss: 0.7533 - val_accuracy: 0.7812 - val_precision: 0.8033 - val_recall: 0.7656 - val_auc: 0.9372 - val_f1_Score: 0.7541 - lr: 1.0000e-04 - 3s/epoch - 344ms/step
# Epoch 50/50
# 10/10 - 3s - loss: 0.1119 - accuracy: 0.9656 - precision: 0.9747 - recall: 0.9625 - auc: 0.9977 - f1_Score: 0.9539 - val_loss: 0.9126 - val_accuracy: 0.8281 - val_precision: 0.8413 - val_recall: 0.8281 - val_auc: 0.9226 - val_f1_Score: 0.7800 - lr: 1.0000e-04 - 3s/epoch - 340ms/step

# %% [markdown]
# ## **5. Plotting the Model Metrics**
# ### i. Plotting training and validation accuracy, loss and learning rate

# %%
plt.figure( figsize = (15,8)) 
    
plt.subplot(221)  
# Accuracy 
plt.plot(model.history.history['accuracy'])
plt.plot(model.history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training set', 'Validation set'], loc='upper left')
plt.show()


# Loss
plt.figure( figsize = (15,8)) 
plt.subplot(222)  
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training set', 'Validation set'], loc='upper left')
plt.show()

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

learning_rate = history.history['lr']
val_loss
# Out:
# [618.3221435546875,
#  266.9283447265625,
#  207.66146850585938,
#  99.63169860839844,
#  11223.7119140625,
#  2014.075927734375,
#  359.02734375,
#  99.52207946777344,
#  382.0920104980469,
#  35.91192626953125,
#  23.609790802001953,
#  32.29875946044922,
#  7.005793571472168,
#  19.214065551757812,
#  5.082852363586426,
#  2.7449581623077393,
#  5.303950309753418,
#  14.405451774597168,
#  19.949981689453125,
#  9.8165283203125,
#  11.086613655090332,
#  6.7200446128845215,
#  3.364593744277954,
#  2.3162152767181396,
#  1.738250494003296,
#  1.4107918739318848,
#  0.75328528881073,
#  0.797343909740448,
#  1.8160436153411865,
#  1.5552406311035156,
#  2.1073226928710938,
#  2.8671443462371826,
#  1.5448124408721924,
#  0.9131617546081543,
#  0.9738093018531799,
#  0.9960826635360718,
#  0.7271702289581299,
#  1.091087818145752,
#  1.1282453536987305,
#  0.8936246037483215,
#  1.017667531967163,
#  0.704459011554718,
#  1.073361873626709,
#  0.766777515411377,
#  0.7066730260848999,
#  0.5088700652122498,
#  0.8141810894012451,
#  0.4894573390483856,
#  0.7532769441604614,
#  0.9126415252685547]

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Testing the Model on Test Set
# Testing the model on the validation dataset because a seperate dataset for testing is not available.

# %%
test_dataset = '/content/drive/MyDrive/Monkeypox_Skin_Image_Dataset/Test'

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255)

test_generator = test_datagen.flow_from_directory(test_dataset,
                                                 shuffle=False,
                                                 batch_size=32,
                                                 target_size = (150,150),
                                                 class_mode='categorical')
# Out:
# Found 241 images belonging to 4 classes.

# %%
predictions = model.predict(test_generator)

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        predicted_label = labels[np.argmax(predictions[idx])]
        ax[i, j].set_title(f"{predicted_label}")
        ax[i, j].imshow(test_generator[0][0][idx])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Test Dataset Predictions", fontsize=20)
plt.show()

# %%
train_loss, train_accuracy, train_precision, train_recall, train_auc, train_F1_Score = model.evaluate(train_generator, batch_size=32)
# Out:
# 17/17 [==============================] - 5s 284ms/step - loss: 0.0678 - accuracy: 0.9760 - precision: 0.9795 - recall: 0.9723 - auc: 0.9992 - f1_Score: 0.9676

# %%
print(f"Train Loss:     {train_loss *100}")
print(f"Train Accuracy: {train_accuracy*100}")
print(f"Train Precision: {train_precision*100}")
print(f"Train Recall: {train_recall*100}")
print(f"Train AUC: {train_auc*100}")
print(f"Train F1_Score: {np.mean(train_F1_Score)*100}")
# Out:
# Train Loss:     6.784405559301376
# Train Accuracy: 97.5970447063446
# Train Precision: 97.95158505439758
# Train Recall: 97.2273588180542
# Train AUC: 99.92368817329407
# Train F1_Score: 96.76365256309509

# %%
test_loss, test_accuracy, test_precision, test_recall, test_auc, test_F1_Score = model.evaluate(test_generator, batch_size=32)
# Out:
# 8/8 [==============================] - 1s 157ms/step - loss: 0.7423 - accuracy: 0.8174 - precision: 0.8333 - recall: 0.8091 - auc: 0.9410 - f1_Score: 0.7683

# %%
print(f"Test Loss:     {test_loss*100}")
print(f"Test Accuracy: {test_accuracy*100}")
print(f"Test Precision: {test_precision*100}")
print(f"Test Recall: {test_recall*100}")
print(f"Test AUC: {test_auc*100}")
print(f"Test F1_Score: {np.mean(test_F1_Score)*100}")
# Out:
# Test Loss:     74.23480153083801
# Test Accuracy: 81.7427396774292
# Test Precision: 83.33333134651184
# Test Recall: 80.91286420822144
# Test AUC: 94.10363435745239
# Test F1_Score: 76.83196067810059

# %% [markdown]
# ## **8. Plotting the Classification Metrics**
# ### i. Confusion Matrix

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# %%
cf_mtx = confusion_matrix(y_true, y_pred)

group_counts = ["{0:0.0f}".format(value) for value in cf_mtx.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_mtx.flatten()/np.sum(cf_mtx)]
box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
box_labels = np.asarray(box_labels).reshape(4, 4)

plt.figure(figsize = (12, 10))
sns.heatmap(cf_mtx, xticklabels=labels.values(), yticklabels=labels.values(),
           cmap="YlGnBu", fmt="", annot=box_labels)
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')
plt.show()

# %%
print(classification_report(y_true, y_pred, target_names=labels.values()))
# Out:
#               precision    recall  f1-score   support
#
#   Chickenpox       0.59      0.50      0.54        34
#      Measles       0.80      0.77      0.79        31
#    Monkeypox       0.77      0.94      0.85        87
#       Normal       0.97      0.83      0.90        89
#
#     accuracy                           0.82       241
#    macro avg       0.78      0.76      0.77       241
# weighted avg       0.82      0.82      0.82       241

# %% [markdown]
# ## **9. Wrong Predictions**
# Let's see where the model has given wrong predictions and what were the actual predictions on those images

# %%
errors = (y_true - y_pred != 0)
y_true_errors = y_true[errors]
y_pred_errors = y_pred[errors]

# %%
test_images = test_generator.filenames
test_img = np.asarray(test_images)[errors]

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        idx = np.random.randint(0, len(test_img))
        true_index = y_true_errors[idx]
        true_label = labels[true_index]
        predicted_index = y_pred_errors[idx]
        predicted_label = labels[predicted_index]
        ax[i, j].set_title(f"True Label: {true_label} \n Predicted Label: {predicted_label}")
        img_path = os.path.join(test_dataset, test_img[idx])
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        ax[i, j].imshow(img)
        ax[i, j].axis("off")

plt.tight_layout()
plt.suptitle('Wrong Predictions made on test set', fontsize=20)
plt.show()
