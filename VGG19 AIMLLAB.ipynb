# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Importing necessary packages**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import cv2
import os
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPool2D,MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator
# from tf.keras.applications import VGG16
from keras import models, layers, optimizers
import matplotlib.image as mpimg
import math

import os

# %% [markdown]
# ## **2. Load the Image Training and Validation Datasets**
#
# ### i. Get the Image Dataset Paths

# %%
train_dataset_path = '/content/drive/MyDrive/Monkeypox_Skin_Image_Dataset/Train'
validation_dataset_path = '/content/drive/MyDrive/Monkeypox_Skin_Image_Dataset/Test'

# %% [markdown]
# ### ii. Load Image Datasets and Apply Augmentations
# Since the images present in the datasets are 150x150px in size, the image height and width are taken as 150, 150 respectively. The batch size value can be changed if required.

# %%
IMG_WIDTH = 150
IMG_HEIGHT = 150
BATCH_SIZE = 32

# %% [markdown]
# Loading the training dataset and applying augmentations on it.

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                  zoom_range=0.2,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  fill_mode='nearest')
train_generator = train_datagen.flow_from_directory(train_dataset_path,
                                                   target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                   batch_size=BATCH_SIZE,
                                                   class_mode='categorical',
                                                   shuffle=True)
# Out:
# Found 541 images belonging to 4 classes.

# %% [markdown]
# Loading the validation dataset.

# %%
validation_datagen = ImageDataGenerator(rescale=1.0/255)
validation_generator = validation_datagen.flow_from_directory(validation_dataset_path,
                                                             target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                             batch_size=BATCH_SIZE,
                                                             class_mode='categorical',
                                                             shuffle=True)
# Out:
# Found 241 images belonging to 4 classes.

# %% [markdown]
# ### iii. Get the Label Mappings
# The labels dictionary is made in order to retrive the class names against the label indices used for training the model

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : Chickenpox
# 1 : Measles
# 2 : Monkeypox
# 3 : Normal

# %% [markdown]
# ## **3. Plotting Sample Training Image**s

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx = 0

for i in range(2):
    for j in range(5):
        label = labels[np.argmax(train_generator[0][1][idx])]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()
# CLASS_NAMES = ['Chickenpox','Measles','Monkeypoxg','Normal']

# %% [markdown]
# ## **4. Training a VGG19 Model**
#
#
# ### i. Create a VGG19 Model

# %%
base_model=tf.keras.applications.VGG19(
   weights = 'imagenet',
   include_top = False,
   input_shape = (150,150,3)
)
base_model.trainable=True
model = models.Sequential()
model.add(base_model)
model.add(layers.Flatten())
model.add(layers.Dense(250, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(4, activation='softmax'))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step
# 80150528/80134624 [==============================] - 1s 0us/step

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 4, 4, 512)         20024384
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 250)               2048250
#
#  dropout (Dropout)           (None, 250)               0
#
#  dense_1 (Dense)             (None, 4)                 1004
#
# =================================================================
# Total params: 22,073,638
# Trainable params: 22,073,638
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### ii. Defining Callbacks
# A callback is an object that can perform actions at various stages of training (e.g. at the start or end of an epoch, before or after a single batch, etc)
#
# a. Reduce Learning Rate on Plateau
# Is used to reduce the learning rate when a metric has stopped improving.

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)
# early = tf.keras.callbacks.EarlyStopping( patience=10,
#                                           min_delta=0.001,
#                                           restore_best_weights=True)

# %% [markdown]
# ### iii. Defining the Optimizer

# %%
optimizer = Adam(learning_rate=0.001)

# %% [markdown]
# ### iv. Compile the Model

# %%
# !pip install tensorflow_addons
import tensorflow_addons as tfa
METRICS = [
      # tf.keras.metrics.BinaryAccuracy(name='binary_accuracy'),
      # tf.keras.metrics.Accuracy(name='accuracy'),
      tf.keras.metrics.CategoricalAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
      # tf.keras.metrics.F1Score(name='F1'),
      tfa.metrics.F1Score(num_classes= 4,name="f1_Score")

    
]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.18.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 5.1 MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow_addons) (3.0.9)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.18.0

# %%
model.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=METRICS)

# %% [markdown]
# ### v. Training the Model

# %%
history = model.fit(train_generator,
                    steps_per_epoch=10,
                    validation_data=validation_generator,
                    validation_steps=2,
                    epochs=50,verbose = 2,
                    callbacks=[reduce_lr])
# Out:
# Epoch 1/50
# 10/10 - 117s - loss: 4.3248 - accuracy: 0.2965 - precision: 0.2460 - recall: 0.0978 - auc: 0.5308 - f1_Score: 0.2257 - val_loss: 1.3208 - val_accuracy: 0.3906 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6702 - val_f1_Score: 0.1404 - lr: 0.0010 - 117s/epoch - 12s/step
# Epoch 2/50
# 10/10 - 41s - loss: 1.3644 - accuracy: 0.4448 - precision: 0.4308 - recall: 0.0883 - auc: 0.6699 - f1_Score: 0.2671 - val_loss: 1.3169 - val_accuracy: 0.5312 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6751 - val_f1_Score: 0.3108 - lr: 0.0010 - 41s/epoch - 4s/step
# Epoch 3/50
# 10/10 - 23s - loss: 1.2884 - accuracy: 0.3844 - precision: 0.5357 - recall: 0.0469 - auc: 0.6639 - f1_Score: 0.2200 - val_loss: 1.2873 - val_accuracy: 0.3750 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6862 - val_f1_Score: 0.1364 - lr: 0.0010 - 23s/epoch - 2s/step
# Epoch 4/50
# 10/10 - 11s - loss: 1.2852 - accuracy: 0.3785 - precision: 0.5714 - recall: 0.0126 - auc: 0.6634 - f1_Score: 0.2004 - val_loss: 1.3639 - val_accuracy: 0.3750 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6503 - val_f1_Score: 0.1364 - lr: 0.0010 - 11s/epoch - 1s/step
# Epoch 5/50
# 10/10 - 7s - loss: 1.3006 - accuracy: 0.3969 - precision: 0.4545 - recall: 0.0625 - auc: 0.6562 - f1_Score: 0.2277 - val_loss: 1.2621 - val_accuracy: 0.4219 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7218 - val_f1_Score: 0.1484 - lr: 0.0010 - 7s/epoch - 744ms/step
# Epoch 6/50
# 10/10 - 7s - loss: 1.2668 - accuracy: 0.3938 - precision: 0.2857 - recall: 0.0063 - auc: 0.6659 - f1_Score: 0.2135 - val_loss: 1.2162 - val_accuracy: 0.3750 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7390 - val_f1_Score: 0.1364 - lr: 0.0010 - 7s/epoch - 695ms/step
# Epoch 7/50
# 10/10 - 4s - loss: 1.2504 - accuracy: 0.4156 - precision: 0.6216 - recall: 0.0719 - auc: 0.6886 - f1_Score: 0.2304 - val_loss: 1.2759 - val_accuracy: 0.6094 - val_precision: 0.5625 - val_recall: 0.1406 - val_auc: 0.6994 - val_f1_Score: 0.3584 - lr: 0.0010 - 4s/epoch - 445ms/step
# Epoch 8/50
# 10/10 - 5s - loss: 1.2916 - accuracy: 0.4500 - precision: 0.4941 - recall: 0.1312 - auc: 0.6740 - f1_Score: 0.2617 - val_loss: 1.2508 - val_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7104 - val_f1_Score: 0.2559 - lr: 0.0010 - 5s/epoch - 510ms/step
# Epoch 9/50
# 10/10 - 4s - loss: 1.2830 - accuracy: 0.4437 - precision: 0.4694 - recall: 0.1437 - auc: 0.6796 - f1_Score: 0.2502 - val_loss: 1.3668 - val_accuracy: 0.1562 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5906 - val_f1_Score: 0.0843 - lr: 0.0010 - 4s/epoch - 424ms/step
# Epoch 10/50
# 10/10 - 4s - loss: 1.2747 - accuracy: 0.4574 - precision: 0.6000 - recall: 0.0473 - auc: 0.6802 - f1_Score: 0.2550 - val_loss: 1.2012 - val_accuracy: 0.5156 - val_precision: 0.5333 - val_recall: 0.1250 - val_auc: 0.7347 - val_f1_Score: 0.2964 - lr: 0.0010 - 4s/epoch - 367ms/step
# Epoch 11/50
# 10/10 - 3s - loss: 1.2031 - accuracy: 0.5094 - precision: 0.5870 - recall: 0.1688 - auc: 0.7259 - f1_Score: 0.2907 - val_loss: 1.2317 - val_accuracy: 0.4688 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7171 - val_f1_Score: 0.2111 - lr: 0.0010 - 3s/epoch - 349ms/step
# Epoch 12/50
# 10/10 - 4s - loss: 1.1894 - accuracy: 0.5489 - precision: 0.6531 - recall: 0.3028 - auc: 0.7328 - f1_Score: 0.3163 - val_loss: 1.0965 - val_accuracy: 0.6562 - val_precision: 0.6364 - val_recall: 0.4375 - val_auc: 0.7691 - val_f1_Score: 0.3789 - lr: 0.0010 - 4s/epoch - 351ms/step
# Epoch 13/50
# 10/10 - 4s - loss: 1.1503 - accuracy: 0.5469 - precision: 0.6068 - recall: 0.3906 - auc: 0.7537 - f1_Score: 0.3123 - val_loss: 1.2343 - val_accuracy: 0.5781 - val_precision: 0.5610 - val_recall: 0.3594 - val_auc: 0.7254 - val_f1_Score: 0.3355 - lr: 0.0010 - 4s/epoch - 400ms/step
# Epoch 14/50
# 10/10 - 4s - loss: 1.2063 - accuracy: 0.5016 - precision: 0.5246 - recall: 0.3028 - auc: 0.7355 - f1_Score: 0.2853 - val_loss: 1.1931 - val_accuracy: 0.4375 - val_precision: 0.5897 - val_recall: 0.3594 - val_auc: 0.7203 - val_f1_Score: 0.1738 - lr: 0.0010 - 4s/epoch - 401ms/step
# Epoch 15/50
# 10/10 - 3s - loss: 1.1632 - accuracy: 0.5281 - precision: 0.6149 - recall: 0.3094 - auc: 0.7491 - f1_Score: 0.3011 - val_loss: 1.1200 - val_accuracy: 0.6094 - val_precision: 0.6750 - val_recall: 0.4219 - val_auc: 0.7516 - val_f1_Score: 0.3527 - lr: 0.0010 - 3s/epoch - 349ms/step
# Epoch 16/50
# 10/10 - 3s - loss: 1.0852 - accuracy: 0.5899 - precision: 0.6699 - recall: 0.4416 - auc: 0.7867 - f1_Score: 0.3346 - val_loss: 1.1967 - val_accuracy: 0.5000 - val_precision: 0.5909 - val_recall: 0.4062 - val_auc: 0.7408 - val_f1_Score: 0.2940 - lr: 0.0010 - 3s/epoch - 345ms/step
# Epoch 17/50
# 10/10 - 3s - loss: 1.1266 - accuracy: 0.5804 - precision: 0.6432 - recall: 0.4322 - auc: 0.7726 - f1_Score: 0.3291 - val_loss: 1.0520 - val_accuracy: 0.6250 - val_precision: 0.6304 - val_recall: 0.4531 - val_auc: 0.7969 - val_f1_Score: 0.3649 - lr: 0.0010 - 3s/epoch - 345ms/step
# Epoch 18/50
# 10/10 - 3s - loss: 1.1006 - accuracy: 0.5688 - precision: 0.6524 - recall: 0.4281 - auc: 0.7807 - f1_Score: 0.3242 - val_loss: 1.1666 - val_accuracy: 0.5312 - val_precision: 0.6190 - val_recall: 0.4062 - val_auc: 0.7423 - val_f1_Score: 0.3095 - lr: 0.0010 - 3s/epoch - 349ms/step
# Epoch 19/50
# 10/10 - 3s - loss: 1.1150 - accuracy: 0.5773 - precision: 0.6526 - recall: 0.3912 - auc: 0.7707 - f1_Score: 0.3336 - val_loss: 0.9602 - val_accuracy: 0.6562 - val_precision: 0.7568 - val_recall: 0.4375 - val_auc: 0.8501 - val_f1_Score: 0.3698 - lr: 0.0010 - 3s/epoch - 347ms/step
# Epoch 20/50
# 10/10 - 3s - loss: 1.0776 - accuracy: 0.5773 - precision: 0.6919 - recall: 0.4606 - auc: 0.7892 - f1_Score: 0.3430 - val_loss: 1.0989 - val_accuracy: 0.5781 - val_precision: 0.6585 - val_recall: 0.4219 - val_auc: 0.7793 - val_f1_Score: 0.3311 - lr: 0.0010 - 3s/epoch - 347ms/step
# Epoch 21/50
# 10/10 - 3s - loss: 1.0989 - accuracy: 0.5584 - precision: 0.6488 - recall: 0.4196 - auc: 0.7824 - f1_Score: 0.3222 - val_loss: 1.0011 - val_accuracy: 0.6094 - val_precision: 0.8182 - val_recall: 0.4219 - val_auc: 0.8402 - val_f1_Score: 0.3358 - lr: 0.0010 - 3s/epoch - 348ms/step
# Epoch 22/50
# 10/10 - 4s - loss: 1.1491 - accuracy: 0.5531 - precision: 0.6513 - recall: 0.3094 - auc: 0.7571 - f1_Score: 0.3176 - val_loss: 1.3002 - val_accuracy: 0.4688 - val_precision: 0.5122 - val_recall: 0.3281 - val_auc: 0.7145 - val_f1_Score: 0.2762 - lr: 0.0010 - 4s/epoch - 357ms/step
# Epoch 23/50
# 10/10 - 4s - loss: 1.1268 - accuracy: 0.5457 - precision: 0.6882 - recall: 0.3691 - auc: 0.7644 - f1_Score: 0.3170 - val_loss: 1.1491 - val_accuracy: 0.6094 - val_precision: 0.6977 - val_recall: 0.4688 - val_auc: 0.7756 - val_f1_Score: 0.3652 - lr: 0.0010 - 4s/epoch - 352ms/step
# Epoch 24/50
# 10/10 - 3s - loss: 1.1436 - accuracy: 0.5584 - precision: 0.6460 - recall: 0.3281 - auc: 0.7567 - f1_Score: 0.3246 - val_loss: 0.9817 - val_accuracy: 0.6562 - val_precision: 0.6977 - val_recall: 0.4688 - val_auc: 0.8321 - val_f1_Score: 0.3755 - lr: 0.0010 - 3s/epoch - 347ms/step
# Epoch 25/50
# 10/10 - 3s - loss: 1.0647 - accuracy: 0.5656 - precision: 0.7120 - recall: 0.4094 - auc: 0.7954 - f1_Score: 0.3401 - val_loss: 1.1196 - val_accuracy: 0.5312 - val_precision: 0.6591 - val_recall: 0.4531 - val_auc: 0.7754 - val_f1_Score: 0.3161 - lr: 3.1623e-04 - 3s/epoch - 344ms/step
# Epoch 26/50
# 10/10 - 3s - loss: 1.0602 - accuracy: 0.5931 - precision: 0.7005 - recall: 0.4132 - auc: 0.7929 - f1_Score: 0.3545 - val_loss: 1.1801 - val_accuracy: 0.4844 - val_precision: 0.5897 - val_recall: 0.3594 - val_auc: 0.7416 - val_f1_Score: 0.2955 - lr: 3.1623e-04 - 3s/epoch - 340ms/step
# Epoch 27/50
# 10/10 - 3s - loss: 1.0618 - accuracy: 0.5931 - precision: 0.6912 - recall: 0.4448 - auc: 0.7974 - f1_Score: 0.3400 - val_loss: 1.0847 - val_accuracy: 0.5312 - val_precision: 0.7143 - val_recall: 0.4688 - val_auc: 0.7885 - val_f1_Score: 0.3167 - lr: 3.1623e-04 - 3s/epoch - 349ms/step
# Epoch 28/50
# 10/10 - 4s - loss: 1.0802 - accuracy: 0.5678 - precision: 0.6699 - recall: 0.4416 - auc: 0.7906 - f1_Score: 0.3302 - val_loss: 1.0930 - val_accuracy: 0.5781 - val_precision: 0.6200 - val_recall: 0.4844 - val_auc: 0.7835 - val_f1_Score: 0.3381 - lr: 3.1623e-04 - 4s/epoch - 352ms/step
# Epoch 29/50
# 10/10 - 3s - loss: 1.0499 - accuracy: 0.6151 - precision: 0.7085 - recall: 0.4448 - auc: 0.7949 - f1_Score: 0.3662 - val_loss: 1.1171 - val_accuracy: 0.5781 - val_precision: 0.6944 - val_recall: 0.3906 - val_auc: 0.7634 - val_f1_Score: 0.3323 - lr: 3.1623e-04 - 3s/epoch - 346ms/step
# Epoch 30/50
# 10/10 - 3s - loss: 1.0413 - accuracy: 0.6025 - precision: 0.7486 - recall: 0.4322 - auc: 0.8104 - f1_Score: 0.3567 - val_loss: 1.1049 - val_accuracy: 0.5469 - val_precision: 0.7273 - val_recall: 0.3750 - val_auc: 0.7841 - val_f1_Score: 0.3069 - lr: 1.0000e-04 - 3s/epoch - 347ms/step
# Epoch 31/50
# 10/10 - 4s - loss: 1.0304 - accuracy: 0.5875 - precision: 0.7401 - recall: 0.4094 - auc: 0.8159 - f1_Score: 0.3436 - val_loss: 1.2226 - val_accuracy: 0.4531 - val_precision: 0.6389 - val_recall: 0.3594 - val_auc: 0.7227 - val_f1_Score: 0.2715 - lr: 1.0000e-04 - 4s/epoch - 350ms/step
# Epoch 32/50
# 10/10 - 3s - loss: 1.0400 - accuracy: 0.6151 - precision: 0.7264 - recall: 0.4606 - auc: 0.8091 - f1_Score: 0.3550 - val_loss: 1.1156 - val_accuracy: 0.5781 - val_precision: 0.6667 - val_recall: 0.5000 - val_auc: 0.7757 - val_f1_Score: 0.3360 - lr: 1.0000e-04 - 3s/epoch - 350ms/step
# Epoch 33/50
# 10/10 - 3s - loss: 1.0349 - accuracy: 0.6025 - precision: 0.7121 - recall: 0.4448 - auc: 0.8093 - f1_Score: 0.3532 - val_loss: 1.0207 - val_accuracy: 0.5781 - val_precision: 0.7436 - val_recall: 0.4531 - val_auc: 0.8101 - val_f1_Score: 0.3171 - lr: 1.0000e-04 - 3s/epoch - 343ms/step
# Epoch 34/50
# 10/10 - 3s - loss: 1.0091 - accuracy: 0.6120 - precision: 0.7563 - recall: 0.4700 - auc: 0.8195 - f1_Score: 0.3524 - val_loss: 1.1280 - val_accuracy: 0.5625 - val_precision: 0.6744 - val_recall: 0.4531 - val_auc: 0.7680 - val_f1_Score: 0.3254 - lr: 1.0000e-04 - 3s/epoch - 344ms/step
# Epoch 35/50
# 10/10 - 3s - loss: 0.9984 - accuracy: 0.6278 - precision: 0.7379 - recall: 0.4795 - auc: 0.8237 - f1_Score: 0.3595 - val_loss: 1.0710 - val_accuracy: 0.5938 - val_precision: 0.6889 - val_recall: 0.4844 - val_auc: 0.7976 - val_f1_Score: 0.3485 - lr: 3.1623e-05 - 3s/epoch - 346ms/step
# Epoch 36/50
# 10/10 - 3s - loss: 1.0344 - accuracy: 0.5899 - precision: 0.6901 - recall: 0.4637 - auc: 0.8074 - f1_Score: 0.3435 - val_loss: 1.0828 - val_accuracy: 0.5469 - val_precision: 0.6875 - val_recall: 0.5156 - val_auc: 0.7950 - val_f1_Score: 0.3147 - lr: 3.1623e-05 - 3s/epoch - 350ms/step
# Epoch 37/50
# 10/10 - 3s - loss: 0.9852 - accuracy: 0.5994 - precision: 0.7183 - recall: 0.4826 - auc: 0.8256 - f1_Score: 0.3434 - val_loss: 1.0342 - val_accuracy: 0.6094 - val_precision: 0.6735 - val_recall: 0.5156 - val_auc: 0.8099 - val_f1_Score: 0.3421 - lr: 3.1623e-05 - 3s/epoch - 349ms/step
# Epoch 38/50
# 10/10 - 3s - loss: 1.0025 - accuracy: 0.5931 - precision: 0.7115 - recall: 0.4669 - auc: 0.8250 - f1_Score: 0.3418 - val_loss: 1.0511 - val_accuracy: 0.5938 - val_precision: 0.6818 - val_recall: 0.4688 - val_auc: 0.8073 - val_f1_Score: 0.3421 - lr: 3.1623e-05 - 3s/epoch - 343ms/step
# Epoch 39/50
# 10/10 - 3s - loss: 1.0282 - accuracy: 0.5969 - precision: 0.7075 - recall: 0.4688 - auc: 0.8159 - f1_Score: 0.3579 - val_loss: 1.2731 - val_accuracy: 0.4844 - val_precision: 0.5238 - val_recall: 0.3438 - val_auc: 0.7128 - val_f1_Score: 0.2886 - lr: 3.1623e-05 - 3s/epoch - 345ms/step
# Epoch 40/50
# 10/10 - 3s - loss: 0.9617 - accuracy: 0.6372 - precision: 0.7407 - recall: 0.5047 - auc: 0.8404 - f1_Score: 0.3646 - val_loss: 1.1334 - val_accuracy: 0.5312 - val_precision: 0.6591 - val_recall: 0.4531 - val_auc: 0.7643 - val_f1_Score: 0.3166 - lr: 1.0000e-05 - 3s/epoch - 341ms/step
# Epoch 41/50
# 10/10 - 3s - loss: 0.9539 - accuracy: 0.6313 - precision: 0.7243 - recall: 0.4844 - auc: 0.8394 - f1_Score: 0.3752 - val_loss: 0.9647 - val_accuracy: 0.6094 - val_precision: 0.7083 - val_recall: 0.5312 - val_auc: 0.8407 - val_f1_Score: 0.3355 - lr: 1.0000e-05 - 3s/epoch - 346ms/step
# Epoch 42/50
# 10/10 - 3s - loss: 0.9547 - accuracy: 0.6246 - precision: 0.7297 - recall: 0.5110 - auc: 0.8380 - f1_Score: 0.3615 - val_loss: 1.3315 - val_accuracy: 0.4844 - val_precision: 0.5306 - val_recall: 0.4062 - val_auc: 0.7031 - val_f1_Score: 0.2929 - lr: 1.0000e-05 - 3s/epoch - 346ms/step
# Epoch 43/50
# 10/10 - 3s - loss: 1.0121 - accuracy: 0.6057 - precision: 0.7000 - recall: 0.4637 - auc: 0.8226 - f1_Score: 0.3538 - val_loss: 1.1994 - val_accuracy: 0.5312 - val_precision: 0.5814 - val_recall: 0.3906 - val_auc: 0.7472 - val_f1_Score: 0.3125 - lr: 1.0000e-05 - 3s/epoch - 344ms/step
# Epoch 44/50
# 10/10 - 3s - loss: 0.9343 - accuracy: 0.6531 - precision: 0.7710 - recall: 0.5156 - auc: 0.8474 - f1_Score: 0.3691 - val_loss: 1.0911 - val_accuracy: 0.5781 - val_precision: 0.6739 - val_recall: 0.4844 - val_auc: 0.7868 - val_f1_Score: 0.3229 - lr: 1.0000e-05 - 3s/epoch - 348ms/step
# Epoch 45/50
# 10/10 - 3s - loss: 1.0012 - accuracy: 0.6025 - precision: 0.7220 - recall: 0.4669 - auc: 0.8250 - f1_Score: 0.3510 - val_loss: 1.0314 - val_accuracy: 0.6094 - val_precision: 0.6889 - val_recall: 0.4844 - val_auc: 0.8018 - val_f1_Score: 0.3499 - lr: 3.1623e-06 - 3s/epoch - 347ms/step
# Epoch 46/50
# 10/10 - 4s - loss: 1.0142 - accuracy: 0.6062 - precision: 0.6808 - recall: 0.4531 - auc: 0.8164 - f1_Score: 0.3525 - val_loss: 1.2356 - val_accuracy: 0.5156 - val_precision: 0.5625 - val_recall: 0.4219 - val_auc: 0.7330 - val_f1_Score: 0.3069 - lr: 3.1623e-06 - 4s/epoch - 351ms/step
# Epoch 47/50
# 10/10 - 3s - loss: 1.0170 - accuracy: 0.6031 - precision: 0.7037 - recall: 0.4750 - auc: 0.8199 - f1_Score: 0.3497 - val_loss: 0.9652 - val_accuracy: 0.6094 - val_precision: 0.7347 - val_recall: 0.5625 - val_auc: 0.8378 - val_f1_Score: 0.3454 - lr: 3.1623e-06 - 3s/epoch - 347ms/step
# Epoch 48/50
# 10/10 - 3s - loss: 0.9211 - accuracy: 0.6625 - precision: 0.7742 - recall: 0.5300 - auc: 0.8488 - f1_Score: 0.3764 - val_loss: 1.0513 - val_accuracy: 0.5781 - val_precision: 0.6667 - val_recall: 0.4688 - val_auc: 0.8029 - val_f1_Score: 0.3413 - lr: 3.1623e-06 - 3s/epoch - 350ms/step
# Epoch 49/50
# 10/10 - 4s - loss: 0.9932 - accuracy: 0.6183 - precision: 0.7356 - recall: 0.4826 - auc: 0.8254 - f1_Score: 0.3563 - val_loss: 1.0311 - val_accuracy: 0.5938 - val_precision: 0.7442 - val_recall: 0.5000 - val_auc: 0.8105 - val_f1_Score: 0.3337 - lr: 3.1623e-06 - 4s/epoch - 360ms/step
# Epoch 50/50
# 10/10 - 4s - loss: 0.9378 - accuracy: 0.6309 - precision: 0.7277 - recall: 0.5142 - auc: 0.8485 - f1_Score: 0.3578 - val_loss: 0.9661 - val_accuracy: 0.6719 - val_precision: 0.7647 - val_recall: 0.6094 - val_auc: 0.8278 - val_f1_Score: 0.3704 - lr: 1.0000e-06 - 4s/epoch - 415ms/step

# %% [markdown]
# ## **5. Plotting the Model Metrics**
# ### i. Plotting training and validation accuracy, loss and learning rate

# %%
plt.figure( figsize = (15,8)) 
    
plt.subplot(221)  
# Accuracy 
plt.plot(model.history.history['accuracy'])
plt.plot(model.history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training set', 'Validation set'], loc='upper left')
plt.show()


# Loss
plt.figure( figsize = (15,8)) 
plt.subplot(222)  
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training set', 'Validation set'], loc='upper left')
plt.show()

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

learning_rate = history.history['lr']
ans = history.history['recall']
ans
# Out:
# [0.09779179841279984,
#  0.08832807838916779,
#  0.046875,
#  0.012618296779692173,
#  0.0625,
#  0.0062500000931322575,
#  0.07187499850988388,
#  0.13124999403953552,
#  0.14374999701976776,
#  0.04731861129403114,
#  0.16875000298023224,
#  0.30283913016319275,
#  0.390625,
#  0.30283913016319275,
#  0.30937498807907104,
#  0.44164037704467773,
#  0.4321766495704651,
#  0.4281249940395355,
#  0.39116719365119934,
#  0.460567831993103,
#  0.4195583462715149,
#  0.30937498807907104,
#  0.3690851628780365,
#  0.32807570695877075,
#  0.40937501192092896,
#  0.4132492244243622,
#  0.4447949528694153,
#  0.44164037704467773,
#  0.4447949528694153,
#  0.4321766495704651,
#  0.40937501192092896,
#  0.460567831993103,
#  0.4447949528694153,
#  0.4700315594673157,
#  0.47949525713920593,
#  0.4637224078178406,
#  0.4826498329639435,
#  0.4668769836425781,
#  0.46875,
#  0.5047318339347839,
#  0.484375,
#  0.511040985584259,
#  0.4637224078178406,
#  0.515625,
#  0.4668769836425781,
#  0.453125,
#  0.4749999940395355,
#  0.5299684405326843,
#  0.4826498329639435,
#  0.5141955614089966]

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Testing the Model on Test Set
# Testing the model on the validation dataset because a seperate dataset for testing is not available.

# %%
test_dataset = '/content/drive/MyDrive/Monkeypox_Skin_Image_Dataset/Test'

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255)

test_generator = test_datagen.flow_from_directory(test_dataset,
                                                 shuffle=False,
                                                 batch_size=BATCH_SIZE,
                                                 target_size = (IMG_WIDTH, IMG_HEIGHT),
                                                 class_mode='categorical')
# Out:
# Found 241 images belonging to 4 classes.

# %% [markdown]
# ## 7. Model Prediction on the Test Dataset

# %%
predictions = model.predict(test_generator)

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        predicted_label = labels[np.argmax(predictions[idx])]
        ax[i, j].set_title(f"{predicted_label}")
        ax[i, j].imshow(test_generator[0][0][idx])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Test Dataset Predictions", fontsize=20)
plt.show()

# %%
train_loss, train_accuracy, train_precision, train_recall, train_auc, train_F1_Score = model.evaluate(train_generator, batch_size=BATCH_SIZE)
# Out:
# 17/17 [==============================] - 4s 252ms/step - loss: 0.9590 - accuracy: 0.6285 - precision: 0.7216 - recall: 0.4935 - auc: 0.8399 - f1_Score: 0.3617

# %%
print(f"Train Loss:     {train_loss}")
print(f"Train Accuracy: {train_accuracy}")
print(f"Train Precision: {train_precision}")
print(f"Train Recall: {train_recall}")
print(f"Train AUC: {train_auc}")
print(f"Train F1_Score: {np.mean(train_F1_Score)}")
# Out:
# Train Loss:     0.9590497016906738
# Train Accuracy: 0.6284658312797546
# Train Precision: 0.7216216325759888
# Train Recall: 0.4935305118560791
# Train AUC: 0.8399343490600586
# Train F1_Score: 0.3617260754108429

# %%
test_loss, test_accuracy, test_precision, test_recall, test_auc, test_F1_Score = model.evaluate(test_generator, batch_size=BATCH_SIZE)
# Out:
# 8/8 [==============================] - 1s 109ms/step - loss: 1.0439 - accuracy: 0.5934 - precision: 0.6851 - recall: 0.5145 - auc: 0.8046 - f1_Score: 0.3417

# %%
print(f"Test Loss:     {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
print(f"Test Precision: {test_precision}")
print(f"Test Recall: {test_recall}")
print(f"Test AUC: {test_auc}")
print(f"Test F1_Score: {np.mean(test_F1_Score)}")
# Out:
# Test Loss:     1.0439295768737793
# Test Accuracy: 0.5933610200881958
# Test Precision: 0.6850828528404236
# Test Recall: 0.5145228505134583
# Test AUC: 0.8045947551727295
# Test F1_Score: 0.34170979261398315

# %% [markdown]
# ## **8. Plotting the Classification Metrics**
# ### i. Confusion Matrix

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# %%
cf_mtx = confusion_matrix(y_true, y_pred)

group_counts = ["{0:0.0f}".format(value) for value in cf_mtx.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_mtx.flatten()/np.sum(cf_mtx)]
box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
box_labels = np.asarray(box_labels).reshape(4, 4)

plt.figure(figsize = (12, 10))
sns.heatmap(cf_mtx, xticklabels=labels.values(), yticklabels=labels.values(),
           cmap="YlGnBu", fmt="", annot=box_labels)
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')
plt.show()

# %%
print(classification_report(y_true, y_pred, target_names=labels.values()))
# Out:
#               precision    recall  f1-score   support
#
#   Chickenpox       0.00      0.00      0.00        34
#      Measles       0.00      0.00      0.00        31
#    Monkeypox       0.58      0.72      0.64        87
#       Normal       0.61      0.90      0.72        89
#
#     accuracy                           0.59       241
#    macro avg       0.30      0.41      0.34       241
# weighted avg       0.43      0.59      0.50       241

# %% [markdown]
# ## **9. Wrong Predictions**
# Let's see where the model has given wrong predictions and what were the actual predictions on those images

# %%
errors = (y_true - y_pred != 0)
y_true_errors = y_true[errors]
y_pred_errors = y_pred[errors]

# %%
test_images = test_generator.filenames
test_img = np.asarray(test_images)[errors]

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        idx = np.random.randint(0, len(test_img))
        true_index = y_true_errors[idx]
        true_label = labels[true_index]
        predicted_index = y_pred_errors[idx]
        predicted_label = labels[predicted_index]
        ax[i, j].set_title(f"True Label: {true_label} \n Predicted Label: {predicted_label}")
        img_path = os.path.join(test_dataset, test_img[idx])
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        ax[i, j].imshow(img)
        ax[i, j].axis("off")

plt.tight_layout()
plt.suptitle('Wrong Predictions made on test set', fontsize=20)
plt.show()
