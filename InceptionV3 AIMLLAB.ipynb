# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Importing necessary packages**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import cv2
import os
# o
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPool2D,MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# %% [markdown]
# ## **2. Load the Image Training and Validation Datasets**
#
# ### i. Get the Image Dataset Paths

# %%
train_dataset_path = '/content/drive/MyDrive/Monkeypox_Skin_Image_Dataset/Train'
validation_dataset_path = '/content/drive/MyDrive/Monkeypox_Skin_Image_Dataset/Test'

# %% [markdown]
# ### ii. Load Image Datasets and Apply Augmentations
# Since the images present in the datasets are 150x150px in size, the image height and width are taken as 150, 150 respectively. The batch size value can be changed if required.

# %%
IMG_WIDTH = 150
IMG_HEIGHT = 150
BATCH_SIZE = 32

# %% [markdown]
# Loading the training dataset and applying augmentations on it.

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                  zoom_range=0.2,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  fill_mode='nearest')
train_generator = train_datagen.flow_from_directory(train_dataset_path,
                                                   target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                   batch_size=BATCH_SIZE,
                                                   class_mode='categorical',
                                                   shuffle=True)
# Out:
# Found 541 images belonging to 4 classes.

# %% [markdown]
# Loading the validation dataset.

# %%
validation_datagen = ImageDataGenerator(rescale=1.0/255)
validation_generator = validation_datagen.flow_from_directory(validation_dataset_path,
                                                             target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                             batch_size=BATCH_SIZE,
                                                             class_mode='categorical',
                                                             shuffle=True)
# Out:
# Found 241 images belonging to 4 classes.

# %% [markdown]
# ### iii. Get the Label Mappings
# The labels dictionary is made in order to retrive the class names against the label indices used for training the model

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : Chickenpox
# 1 : Measles
# 2 : Monkeypox
# 3 : Normal

# %% [markdown]
# ## **3. Plotting Sample Training Image**s

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx = 0

for i in range(2):
    for j in range(5):
        label = labels[np.argmax(train_generator[0][1][idx])]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()
# CLASS_NAMES = ['Chickenpox','Measles','Monkeypoxg','Normal']

# %% [markdown]
# ## **4. Training a InceptionResNetV2 Model**
#
#
# ### i. Create a InceptionResNetV2 Model

# %%
base_model = tf.keras.applications.InceptionV3(
                     include_top=False,
                     weights='imagenet',
                     input_shape=(150,150,3),
                     classifier_activation="softmax"
                     )

base_model.trainable=True
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 0s 0us/step
# 87924736/87910968 [==============================] - 0s 0us/step

# %%
model = tf.keras.Sequential([
        base_model,  
        tf.keras.layers.BatchNormalization(renorm=True),
        tf.keras.layers.GlobalAveragePooling2D(),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(4, activation='softmax')
    ])

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 3, 3, 2048)        21802784
#
#  batch_normalization_94 (Bat  (None, 3, 3, 2048)       14336
#  chNormalization)
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 512)               1049088
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dense_3 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 23,030,948
# Trainable params: 22,986,276
# Non-trainable params: 44,672
# _________________________________________________________________
# None

# %% [markdown]
# ### ii. Defining Callbacks
# A callback is an object that can perform actions at various stages of training (e.g. at the start or end of an epoch, before or after a single batch, etc)
#
# a. Reduce Learning Rate on Plateau
# Is used to reduce the learning rate when a metric has stopped improving.

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)
# !pip install tensorflow_addons
import tensorflow_addons as tfa
METRICS = [
      # tf.keras.metrics.BinaryAccuracy(name='binary_accuracy'),
      # tf.keras.metrics.Accuracy(name='accuracy'),
      tf.keras.metrics.CategoricalAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
      # tf.keras.metrics.F1Score(name='F1'),
      tfa.metrics.F1Score(num_classes= 4,name="f1_Score")

    
]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.18.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 30.9 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (21.3)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow_addons) (3.0.9)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.18.0

# %% [markdown]
# ### iii. Defining the Optimizer

# %%
optimizer = Adam(learning_rate=0.001)

# %% [markdown]
# ### iv. Compile the Model

# %%
# cnn_model.compile(optimizer=optimizer, loss=CategoricalCrossentropy(), metrics=['accuracy'])
model.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=METRICS)

# %% [markdown]
# ### v. Training the Model

# %%
history = model.fit(train_generator,
                    steps_per_epoch=10,
                    validation_data=validation_generator,
                    validation_steps=2,
                    epochs=50,verbose = 2,
                    callbacks=[reduce_lr])
# Out:
# Epoch 1/50
# 10/10 - 195s - loss: 1.1065 - accuracy: 0.5868 - precision: 0.7128 - recall: 0.4227 - auc: 0.8089 - f1_Score: 0.3522 - val_loss: 10.6319 - val_accuracy: 0.3750 - val_precision: 0.3750 - val_recall: 0.3750 - val_auc: 0.5743 - val_f1_Score: 0.1971 - lr: 0.0010 - 195s/epoch - 20s/step
# Epoch 2/50
# 10/10 - 85s - loss: 0.9150 - accuracy: 0.6435 - precision: 0.7857 - recall: 0.5205 - auc: 0.8694 - f1_Score: 0.4837 - val_loss: 66.8936 - val_accuracy: 0.2031 - val_precision: 0.2031 - val_recall: 0.2031 - val_auc: 0.4688 - val_f1_Score: 0.0844 - lr: 0.0010 - 85s/epoch - 9s/step
# Epoch 3/50
# 10/10 - 45s - loss: 0.8122 - accuracy: 0.6751 - precision: 0.8398 - recall: 0.5457 - auc: 0.8892 - f1_Score: 0.5390 - val_loss: 2521.3621 - val_accuracy: 0.3906 - val_precision: 0.3906 - val_recall: 0.3906 - val_auc: 0.5938 - val_f1_Score: 0.1404 - lr: 0.0010 - 45s/epoch - 4s/step
# Epoch 4/50
# 10/10 - 25s - loss: 0.6914 - accuracy: 0.7287 - precision: 0.8489 - recall: 0.6025 - auc: 0.9194 - f1_Score: 0.6412 - val_loss: 1528.7968 - val_accuracy: 0.3281 - val_precision: 0.3281 - val_recall: 0.3281 - val_auc: 0.5521 - val_f1_Score: 0.1235 - lr: 0.0010 - 25s/epoch - 2s/step
# Epoch 5/50
# 10/10 - 15s - loss: 1.0489 - accuracy: 0.7161 - precision: 0.8125 - recall: 0.6151 - auc: 0.8888 - f1_Score: 0.6441 - val_loss: 20669.3203 - val_accuracy: 0.4219 - val_precision: 0.4219 - val_recall: 0.4219 - val_auc: 0.6146 - val_f1_Score: 0.1484 - lr: 0.0010 - 15s/epoch - 2s/step
# Epoch 6/50
# 10/10 - 8s - loss: 1.1130 - accuracy: 0.6812 - precision: 0.7326 - recall: 0.5906 - auc: 0.8723 - f1_Score: 0.5730 - val_loss: 18446.5508 - val_accuracy: 0.4531 - val_precision: 0.4531 - val_recall: 0.4531 - val_auc: 0.6354 - val_f1_Score: 0.1559 - lr: 0.0010 - 8s/epoch - 802ms/step
# Epoch 7/50
# 10/10 - 6s - loss: 0.9316 - accuracy: 0.7375 - precision: 0.8054 - recall: 0.6469 - auc: 0.8916 - f1_Score: 0.6985 - val_loss: 420.7341 - val_accuracy: 0.1094 - val_precision: 0.1094 - val_recall: 0.1094 - val_auc: 0.4062 - val_f1_Score: 0.0493 - lr: 3.1623e-04 - 6s/epoch - 562ms/step
# Epoch 8/50
# 10/10 - 4s - loss: 0.7569 - accuracy: 0.7571 - precision: 0.8145 - recall: 0.7066 - auc: 0.9166 - f1_Score: 0.6782 - val_loss: 17.5518 - val_accuracy: 0.2188 - val_precision: 0.2097 - val_recall: 0.2031 - val_auc: 0.4389 - val_f1_Score: 0.1453 - lr: 3.1623e-04 - 4s/epoch - 373ms/step
# Epoch 9/50
# 10/10 - 4s - loss: 0.6520 - accuracy: 0.7688 - precision: 0.8315 - recall: 0.7250 - auc: 0.9343 - f1_Score: 0.7035 - val_loss: 1.5256 - val_accuracy: 0.3438 - val_precision: 0.3529 - val_recall: 0.2812 - val_auc: 0.7253 - val_f1_Score: 0.2487 - lr: 3.1623e-04 - 4s/epoch - 435ms/step
# Epoch 10/50
# 10/10 - 3s - loss: 0.5392 - accuracy: 0.8044 - precision: 0.8672 - recall: 0.7413 - auc: 0.9531 - f1_Score: 0.7273 - val_loss: 1.3613 - val_accuracy: 0.5156 - val_precision: 0.5472 - val_recall: 0.4531 - val_auc: 0.7836 - val_f1_Score: 0.4015 - lr: 3.1623e-04 - 3s/epoch - 303ms/step
# Epoch 11/50
# 10/10 - 3s - loss: 0.4407 - accuracy: 0.8580 - precision: 0.8707 - recall: 0.8076 - auc: 0.9660 - f1_Score: 0.8114 - val_loss: 1.2463 - val_accuracy: 0.6875 - val_precision: 0.7213 - val_recall: 0.6875 - val_auc: 0.8590 - val_f1_Score: 0.6084 - lr: 3.1623e-04 - 3s/epoch - 303ms/step
# Epoch 12/50
# 10/10 - 4s - loss: 0.3467 - accuracy: 0.8675 - precision: 0.9100 - recall: 0.8297 - auc: 0.9806 - f1_Score: 0.8233 - val_loss: 0.8285 - val_accuracy: 0.7500 - val_precision: 0.8214 - val_recall: 0.7188 - val_auc: 0.9167 - val_f1_Score: 0.6676 - lr: 3.1623e-04 - 4s/epoch - 372ms/step
# Epoch 13/50
# 10/10 - 3s - loss: 0.3286 - accuracy: 0.9117 - precision: 0.9276 - recall: 0.8896 - auc: 0.9806 - f1_Score: 0.8862 - val_loss: 0.9194 - val_accuracy: 0.7344 - val_precision: 0.7541 - val_recall: 0.7188 - val_auc: 0.9048 - val_f1_Score: 0.6836 - lr: 3.1623e-04 - 3s/epoch - 308ms/step
# Epoch 14/50
# 10/10 - 4s - loss: 0.3196 - accuracy: 0.8938 - precision: 0.9186 - recall: 0.8813 - auc: 0.9816 - f1_Score: 0.8576 - val_loss: 1.0805 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.9142 - val_f1_Score: 0.7637 - lr: 3.1623e-04 - 4s/epoch - 374ms/step
# Epoch 15/50
# 10/10 - 3s - loss: 0.3187 - accuracy: 0.8991 - precision: 0.9213 - recall: 0.8864 - auc: 0.9797 - f1_Score: 0.8665 - val_loss: 0.5672 - val_accuracy: 0.8281 - val_precision: 0.8361 - val_recall: 0.7969 - val_auc: 0.9627 - val_f1_Score: 0.8006 - lr: 3.1623e-04 - 3s/epoch - 311ms/step
# Epoch 16/50
# 10/10 - 3s - loss: 0.4256 - accuracy: 0.8770 - precision: 0.8932 - recall: 0.8707 - auc: 0.9672 - f1_Score: 0.8338 - val_loss: 0.6067 - val_accuracy: 0.8594 - val_precision: 0.8833 - val_recall: 0.8281 - val_auc: 0.9447 - val_f1_Score: 0.8304 - lr: 3.1623e-04 - 3s/epoch - 305ms/step
# Epoch 17/50
# 10/10 - 3s - loss: 0.3221 - accuracy: 0.8864 - precision: 0.9145 - recall: 0.8770 - auc: 0.9813 - f1_Score: 0.8557 - val_loss: 1.3775 - val_accuracy: 0.8125 - val_precision: 0.8254 - val_recall: 0.8125 - val_auc: 0.9495 - val_f1_Score: 0.7789 - lr: 3.1623e-04 - 3s/epoch - 308ms/step
# Epoch 18/50
# 10/10 - 3s - loss: 0.3819 - accuracy: 0.8896 - precision: 0.9100 - recall: 0.8612 - auc: 0.9761 - f1_Score: 0.8504 - val_loss: 1.1052 - val_accuracy: 0.7812 - val_precision: 0.7937 - val_recall: 0.7812 - val_auc: 0.9060 - val_f1_Score: 0.7288 - lr: 3.1623e-04 - 3s/epoch - 302ms/step
# Epoch 19/50
# 10/10 - 3s - loss: 0.2718 - accuracy: 0.9022 - precision: 0.9211 - recall: 0.8833 - auc: 0.9847 - f1_Score: 0.8709 - val_loss: 1.2031 - val_accuracy: 0.7812 - val_precision: 0.7937 - val_recall: 0.7812 - val_auc: 0.8943 - val_f1_Score: 0.6905 - lr: 3.1623e-04 - 3s/epoch - 306ms/step
# Epoch 20/50
# 10/10 - 3s - loss: 0.2668 - accuracy: 0.9062 - precision: 0.9167 - recall: 0.8938 - auc: 0.9862 - f1_Score: 0.8793 - val_loss: 0.5877 - val_accuracy: 0.7969 - val_precision: 0.8226 - val_recall: 0.7969 - val_auc: 0.9571 - val_f1_Score: 0.7615 - lr: 3.1623e-04 - 3s/epoch - 309ms/step
# Epoch 21/50
# 10/10 - 3s - loss: 0.3193 - accuracy: 0.8927 - precision: 0.9035 - recall: 0.8864 - auc: 0.9826 - f1_Score: 0.8670 - val_loss: 0.4016 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 0.8438 - val_auc: 0.9837 - val_f1_Score: 0.8132 - lr: 1.0000e-04 - 3s/epoch - 303ms/step
# Epoch 22/50
# 10/10 - 4s - loss: 0.2013 - accuracy: 0.9211 - precision: 0.9351 - recall: 0.9085 - auc: 0.9932 - f1_Score: 0.9007 - val_loss: 0.4323 - val_accuracy: 0.8438 - val_precision: 0.8689 - val_recall: 0.8281 - val_auc: 0.9718 - val_f1_Score: 0.8180 - lr: 1.0000e-04 - 4s/epoch - 368ms/step
# Epoch 23/50
# 10/10 - 3s - loss: 0.1812 - accuracy: 0.9500 - precision: 0.9551 - recall: 0.9312 - auc: 0.9925 - f1_Score: 0.9319 - val_loss: 0.5717 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 0.8438 - val_auc: 0.9612 - val_f1_Score: 0.8009 - lr: 1.0000e-04 - 3s/epoch - 311ms/step
# Epoch 24/50
# 10/10 - 3s - loss: 0.1383 - accuracy: 0.9621 - precision: 0.9678 - recall: 0.9495 - auc: 0.9942 - f1_Score: 0.9420 - val_loss: 0.6108 - val_accuracy: 0.8594 - val_precision: 0.8571 - val_recall: 0.8438 - val_auc: 0.9503 - val_f1_Score: 0.8347 - lr: 1.0000e-04 - 3s/epoch - 305ms/step
# Epoch 25/50
# 10/10 - 3s - loss: 0.1125 - accuracy: 0.9625 - precision: 0.9747 - recall: 0.9625 - auc: 0.9961 - f1_Score: 0.9377 - val_loss: 0.4219 - val_accuracy: 0.9062 - val_precision: 0.9062 - val_recall: 0.9062 - val_auc: 0.9731 - val_f1_Score: 0.8955 - lr: 1.0000e-04 - 3s/epoch - 305ms/step
# Epoch 26/50
# 10/10 - 3s - loss: 0.1323 - accuracy: 0.9594 - precision: 0.9591 - recall: 0.9531 - auc: 0.9967 - f1_Score: 0.9405 - val_loss: 0.3807 - val_accuracy: 0.9062 - val_precision: 0.9062 - val_recall: 0.9062 - val_auc: 0.9760 - val_f1_Score: 0.8444 - lr: 1.0000e-04 - 3s/epoch - 313ms/step
# Epoch 27/50
# 10/10 - 3s - loss: 0.0952 - accuracy: 0.9625 - precision: 0.9684 - recall: 0.9563 - auc: 0.9985 - f1_Score: 0.9495 - val_loss: 0.5614 - val_accuracy: 0.8750 - val_precision: 0.9167 - val_recall: 0.8594 - val_auc: 0.9565 - val_f1_Score: 0.8239 - lr: 1.0000e-04 - 3s/epoch - 316ms/step
# Epoch 28/50
# 10/10 - 3s - loss: 0.1336 - accuracy: 0.9590 - precision: 0.9589 - recall: 0.9558 - auc: 0.9965 - f1_Score: 0.9510 - val_loss: 0.5122 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9584 - val_f1_Score: 0.8483 - lr: 1.0000e-04 - 3s/epoch - 304ms/step
# Epoch 29/50
# 10/10 - 3s - loss: 0.0974 - accuracy: 0.9750 - precision: 0.9748 - recall: 0.9688 - auc: 0.9964 - f1_Score: 0.9662 - val_loss: 0.4134 - val_accuracy: 0.9219 - val_precision: 0.9219 - val_recall: 0.9219 - val_auc: 0.9716 - val_f1_Score: 0.9043 - lr: 1.0000e-04 - 3s/epoch - 307ms/step
# Epoch 30/50
# 10/10 - 3s - loss: 0.1512 - accuracy: 0.9625 - precision: 0.9684 - recall: 0.9563 - auc: 0.9908 - f1_Score: 0.9472 - val_loss: 0.3716 - val_accuracy: 0.9062 - val_precision: 0.9048 - val_recall: 0.8906 - val_auc: 0.9823 - val_f1_Score: 0.8956 - lr: 1.0000e-04 - 3s/epoch - 315ms/step
# Epoch 31/50
# 10/10 - 3s - loss: 0.0828 - accuracy: 0.9719 - precision: 0.9749 - recall: 0.9719 - auc: 0.9971 - f1_Score: 0.9578 - val_loss: 0.1791 - val_accuracy: 0.9375 - val_precision: 0.9524 - val_recall: 0.9375 - val_auc: 0.9953 - val_f1_Score: 0.9335 - lr: 1.0000e-04 - 3s/epoch - 306ms/step
# Epoch 32/50
# 10/10 - 3s - loss: 0.1205 - accuracy: 0.9621 - precision: 0.9713 - recall: 0.9621 - auc: 0.9940 - f1_Score: 0.9539 - val_loss: 0.1295 - val_accuracy: 0.9531 - val_precision: 0.9524 - val_recall: 0.9375 - val_auc: 0.9968 - val_f1_Score: 0.9344 - lr: 1.0000e-04 - 3s/epoch - 308ms/step
# Epoch 33/50
# 10/10 - 3s - loss: 0.1017 - accuracy: 0.9685 - precision: 0.9714 - recall: 0.9653 - auc: 0.9966 - f1_Score: 0.9604 - val_loss: 0.6254 - val_accuracy: 0.8594 - val_precision: 0.8594 - val_recall: 0.8594 - val_auc: 0.9592 - val_f1_Score: 0.8284 - lr: 1.0000e-04 - 3s/epoch - 315ms/step
# Epoch 34/50
# 10/10 - 3s - loss: 0.0896 - accuracy: 0.9748 - precision: 0.9808 - recall: 0.9685 - auc: 0.9984 - f1_Score: 0.9648 - val_loss: 0.5529 - val_accuracy: 0.8906 - val_precision: 0.9016 - val_recall: 0.8594 - val_auc: 0.9668 - val_f1_Score: 0.8866 - lr: 1.0000e-04 - 3s/epoch - 312ms/step
# Epoch 35/50
# 10/10 - 3s - loss: 0.1104 - accuracy: 0.9653 - precision: 0.9683 - recall: 0.9621 - auc: 0.9979 - f1_Score: 0.9502 - val_loss: 0.4512 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9694 - val_f1_Score: 0.8392 - lr: 1.0000e-04 - 3s/epoch - 308ms/step
# Epoch 36/50
# 10/10 - 3s - loss: 0.1236 - accuracy: 0.9716 - precision: 0.9716 - recall: 0.9716 - auc: 0.9937 - f1_Score: 0.9692 - val_loss: 0.5654 - val_accuracy: 0.8906 - val_precision: 0.9048 - val_recall: 0.8906 - val_auc: 0.9574 - val_f1_Score: 0.8897 - lr: 1.0000e-04 - 3s/epoch - 299ms/step
# Epoch 37/50
# 10/10 - 3s - loss: 0.1063 - accuracy: 0.9719 - precision: 0.9717 - recall: 0.9656 - auc: 0.9946 - f1_Score: 0.9613 - val_loss: 0.6365 - val_accuracy: 0.8438 - val_precision: 0.8571 - val_recall: 0.8438 - val_auc: 0.9601 - val_f1_Score: 0.7869 - lr: 1.0000e-04 - 3s/epoch - 306ms/step
# Epoch 38/50
# 10/10 - 3s - loss: 0.0812 - accuracy: 0.9750 - precision: 0.9781 - recall: 0.9750 - auc: 0.9968 - f1_Score: 0.9632 - val_loss: 1.0486 - val_accuracy: 0.8125 - val_precision: 0.8361 - val_recall: 0.7969 - val_auc: 0.9252 - val_f1_Score: 0.7838 - lr: 3.1623e-05 - 3s/epoch - 309ms/step
# Epoch 39/50
# 10/10 - 3s - loss: 0.1049 - accuracy: 0.9590 - precision: 0.9620 - recall: 0.9590 - auc: 0.9963 - f1_Score: 0.9424 - val_loss: 0.6902 - val_accuracy: 0.8438 - val_precision: 0.8983 - val_recall: 0.8281 - val_auc: 0.9460 - val_f1_Score: 0.8179 - lr: 3.1623e-05 - 3s/epoch - 303ms/step
# Epoch 40/50
# 10/10 - 3s - loss: 0.0848 - accuracy: 0.9716 - precision: 0.9776 - recall: 0.9653 - auc: 0.9969 - f1_Score: 0.9609 - val_loss: 0.3845 - val_accuracy: 0.8438 - val_precision: 0.8571 - val_recall: 0.8438 - val_auc: 0.9739 - val_f1_Score: 0.8204 - lr: 3.1623e-05 - 3s/epoch - 304ms/step
# Epoch 41/50
# 10/10 - 3s - loss: 0.0378 - accuracy: 0.9905 - precision: 0.9905 - recall: 0.9905 - auc: 0.9999 - f1_Score: 0.9849 - val_loss: 0.6879 - val_accuracy: 0.9062 - val_precision: 0.9062 - val_recall: 0.9062 - val_auc: 0.9502 - val_f1_Score: 0.8897 - lr: 3.1623e-05 - 3s/epoch - 302ms/step
# Epoch 42/50
# 10/10 - 3s - loss: 0.0746 - accuracy: 0.9812 - precision: 0.9843 - recall: 0.9812 - auc: 0.9986 - f1_Score: 0.9767 - val_loss: 0.3208 - val_accuracy: 0.9219 - val_precision: 0.9365 - val_recall: 0.9219 - val_auc: 0.9816 - val_f1_Score: 0.8646 - lr: 3.1623e-05 - 3s/epoch - 307ms/step
# Epoch 43/50
# 10/10 - 3s - loss: 0.0486 - accuracy: 0.9875 - precision: 0.9937 - recall: 0.9875 - auc: 0.9975 - f1_Score: 0.9836 - val_loss: 0.5181 - val_accuracy: 0.8906 - val_precision: 0.9048 - val_recall: 0.8906 - val_auc: 0.9693 - val_f1_Score: 0.8634 - lr: 1.0000e-05 - 3s/epoch - 303ms/step
# Epoch 44/50
# 10/10 - 3s - loss: 0.0993 - accuracy: 0.9748 - precision: 0.9747 - recall: 0.9716 - auc: 0.9963 - f1_Score: 0.9658 - val_loss: 0.2212 - val_accuracy: 0.9531 - val_precision: 0.9524 - val_recall: 0.9375 - val_auc: 0.9871 - val_f1_Score: 0.9391 - lr: 1.0000e-05 - 3s/epoch - 305ms/step
# Epoch 45/50
# 10/10 - 3s - loss: 0.0517 - accuracy: 0.9779 - precision: 0.9841 - recall: 0.9779 - auc: 0.9995 - f1_Score: 0.9685 - val_loss: 0.5936 - val_accuracy: 0.8750 - val_precision: 0.9032 - val_recall: 0.8750 - val_auc: 0.9492 - val_f1_Score: 0.8406 - lr: 1.0000e-05 - 3s/epoch - 311ms/step
# Epoch 46/50
# 10/10 - 3s - loss: 0.0772 - accuracy: 0.9781 - precision: 0.9812 - recall: 0.9781 - auc: 0.9989 - f1_Score: 0.9716 - val_loss: 0.9986 - val_accuracy: 0.8438 - val_precision: 0.8689 - val_recall: 0.8281 - val_auc: 0.9344 - val_f1_Score: 0.8212 - lr: 1.0000e-05 - 3s/epoch - 306ms/step
# Epoch 47/50
# 10/10 - 3s - loss: 0.0659 - accuracy: 0.9750 - precision: 0.9780 - recall: 0.9719 - auc: 0.9992 - f1_Score: 0.9646 - val_loss: 0.6492 - val_accuracy: 0.8906 - val_precision: 0.9048 - val_recall: 0.8906 - val_auc: 0.9689 - val_f1_Score: 0.8616 - lr: 1.0000e-05 - 3s/epoch - 305ms/step
# Epoch 48/50
# 10/10 - 3s - loss: 0.0403 - accuracy: 0.9875 - precision: 0.9906 - recall: 0.9844 - auc: 0.9976 - f1_Score: 0.9842 - val_loss: 0.5133 - val_accuracy: 0.9062 - val_precision: 0.9062 - val_recall: 0.9062 - val_auc: 0.9724 - val_f1_Score: 0.8926 - lr: 3.1623e-06 - 3s/epoch - 306ms/step
# Epoch 49/50
# 10/10 - 3s - loss: 0.0410 - accuracy: 0.9875 - precision: 0.9875 - recall: 0.9844 - auc: 0.9997 - f1_Score: 0.9815 - val_loss: 0.5425 - val_accuracy: 0.8750 - val_precision: 0.8730 - val_recall: 0.8594 - val_auc: 0.9637 - val_f1_Score: 0.8082 - lr: 3.1623e-06 - 3s/epoch - 304ms/step
# Epoch 50/50
# 10/10 - 3s - loss: 0.0661 - accuracy: 0.9812 - precision: 0.9812 - recall: 0.9781 - auc: 0.9973 - f1_Score: 0.9763 - val_loss: 0.1967 - val_accuracy: 0.9688 - val_precision: 0.9688 - val_recall: 0.9688 - val_auc: 0.9940 - val_f1_Score: 0.9449 - lr: 3.1623e-06 - 3s/epoch - 305ms/step

# %% [markdown]
# ## **5. Plotting the Model Metrics**
# ### i. Plotting training and validation accuracy, loss and learning rate

# %%
plt.figure( figsize = (15,8)) 
    
plt.subplot(221)  
# Accuracy 
plt.plot(model.history.history['accuracy'])
plt.plot(model.history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training set', 'Validation set'], loc='upper left')
plt.show()


# Loss
plt.figure( figsize = (15,8)) 
plt.subplot(222)  
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training set', 'Validation set'], loc='upper left')
plt.show()

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

learning_rate = history.history['lr']
val_loss
# Out:
# [10.63193130493164,
#  66.8935546875,
#  2521.362060546875,
#  1528.7967529296875,
#  20669.3203125,
#  18446.55078125,
#  420.734130859375,
#  17.551773071289062,
#  1.5256285667419434,
#  1.3612666130065918,
#  1.2463290691375732,
#  0.8284673690795898,
#  0.9193840622901917,
#  1.080491065979004,
#  0.567187488079071,
#  0.6066716313362122,
#  1.377516269683838,
#  1.1051723957061768,
#  1.2030656337738037,
#  0.5876612663269043,
#  0.4016258120536804,
#  0.432325154542923,
#  0.5717384219169617,
#  0.6108409762382507,
#  0.42187944054603577,
#  0.3807283639907837,
#  0.5614075064659119,
#  0.5121972560882568,
#  0.4133622348308563,
#  0.37157607078552246,
#  0.17911297082901,
#  0.12946395576000214,
#  0.6254006028175354,
#  0.5528897047042847,
#  0.45115989446640015,
#  0.5653818845748901,
#  0.636509895324707,
#  1.0485879182815552,
#  0.6902019381523132,
#  0.38454359769821167,
#  0.6878794431686401,
#  0.32076168060302734,
#  0.5180831551551819,
#  0.2211645394563675,
#  0.5935943722724915,
#  0.9985511898994446,
#  0.649175763130188,
#  0.5133155584335327,
#  0.5425330400466919,
#  0.19665969908237457]

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %%
def Train_Val_Plot(acc,val_acc,loss,val_loss,auc,val_auc,precision,val_precision,f1_Score,val_f1_Score):
    
    fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])
    
    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('AUC')
    ax3.legend(['training', 'validation'])
    
    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Precision')
    ax4.legend(['training', 'validation'])
    
    ax5.plot(range(1, len(f1_Score) + 1), f1_Score)
    ax5.plot(range(1, len(val_f1_Score) + 1), val_f1_Score)
    ax5.set_title('History of F1-score')
    ax5.set_xlabel('Epochs')
    ax5.set_ylabel('F1 score')
    ax5.legend(['training', 'validation'])


    plt.show()
    
import numpy as np
# f1_s= np.mean(history.history['f1_Score'])
# val_f1_s= np.mean(history.history['val_f1_Score'])
Train_Val_Plot(history.history['accuracy'],history.history['val_accuracy'],
               history.history['loss'],history.history['val_loss'],
               history.history['auc'],history.history['val_auc'],
               history.history['precision'],history.history['val_precision']
              #  f1_s,val_f1_s

                , history.history['f1_Score'],history.history['val_f1_Score'])

# %% [markdown]
# ## 6. Testing the Model on Test Set
# Testing the model on the validation dataset because a seperate dataset for testing is not available.

# %%
test_dataset = '/content/drive/MyDrive/Monkeypox_Skin_Image_Dataset/Test'

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255)

test_generator = test_datagen.flow_from_directory(test_dataset,
                                                 shuffle=False,
                                                 batch_size=BATCH_SIZE,
                                                 target_size = (IMG_WIDTH, IMG_HEIGHT),
                                                 class_mode='categorical')
# Out:
# Found 241 images belonging to 4 classes.

# %% [markdown]
# ## 7. Model Prediction on the Test Dataset

# %%
predictions = model.predict(test_generator)

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        predicted_label = labels[np.argmax(predictions[idx])]
        ax[i, j].set_title(f"{predicted_label}")
        ax[i, j].imshow(test_generator[0][0][idx])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Test Dataset Predictions", fontsize=20)
plt.show()

# %%
train_loss, train_accuracy, train_precision, train_recall, train_auc, train_F1_Score = model.evaluate(train_generator, batch_size=BATCH_SIZE)
# Out:
# 17/17 [==============================] - 4s 242ms/step - loss: 0.0270 - accuracy: 0.9963 - precision: 0.9963 - recall: 0.9963 - auc: 0.9986 - f1_Score: 0.9941

# %%
print(f"Train Loss:     {train_loss *100}")
print(f"Train Accuracy: {train_accuracy *100}")
print(f"Train Precision: {train_precision *100}")
print(f"Train Recall: {train_recall *100}")
print(f"Train AUC: {train_auc *100}")
print(f"Train F1_Score: {np.mean(train_F1_Score) *100}")
# Out:
# Train Loss:     2.6986444368958473
# Train Accuracy: 99.6303141117096
# Train Precision: 99.6303141117096
# Train Recall: 99.6303141117096
# Train AUC: 99.8637318611145
# Train F1_Score: 99.41277503967285

# %%
test_loss, test_accuracy, test_precision, test_recall, test_auc, test_F1_Score = model.evaluate(test_generator, batch_size=BATCH_SIZE)
# Out:
# 8/8 [==============================] - 1s 97ms/step - loss: 0.5697 - accuracy: 0.8963 - precision: 0.8958 - recall: 0.8921 - auc: 0.9665 - f1_Score: 0.8727

# %%
print(f"Test Loss:     {test_loss*100}")
print(f"Test Accuracy: {test_accuracy*100}")
print(f"Test Precision: {test_precision*100}")
print(f"Test Recall: {test_recall*100}")
print(f"Test AUC: {test_auc*100}")
print(f"Test F1_Score: {np.mean(test_F1_Score)*100}")
# Out:
# Test Loss:     56.97051286697388
# Test Accuracy: 89.62655663490295
# Test Precision: 89.58333134651184
# Test Recall: 89.21161890029907
# Test AUC: 96.65180444717407
# Test F1_Score: 87.26806640625

# %% [markdown]
# ## **8. Plotting the Classification Metrics**
# ### i. Confusion Matrix

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# %%
cf_mtx = confusion_matrix(y_true, y_pred)

group_counts = ["{0:0.0f}".format(value) for value in cf_mtx.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_mtx.flatten()/np.sum(cf_mtx)]
box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
box_labels = np.asarray(box_labels).reshape(4, 4)

plt.figure(figsize = (12, 10))
sns.heatmap(cf_mtx, xticklabels=labels.values(), yticklabels=labels.values(),
           cmap="YlGnBu", fmt="", annot=box_labels)
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')
plt.show()

# %%
print(classification_report(y_true, y_pred, target_names=labels.values()))
# Out:
#               precision    recall  f1-score   support
#
#   Chickenpox       0.73      0.71      0.72        34
#      Measles       0.88      0.97      0.92        31
#    Monkeypox       0.91      0.91      0.91        87
#       Normal       0.95      0.93      0.94        89
#
#     accuracy                           0.90       241
#    macro avg       0.87      0.88      0.87       241
# weighted avg       0.90      0.90      0.90       241

# %% [markdown]
# ## **9. Wrong Predictions**
# Let's see where the model has given wrong predictions and what were the actual predictions on those images

# %%
errors = (y_true - y_pred != 0)
y_true_errors = y_true[errors]
y_pred_errors = y_pred[errors]

# %%
test_images = test_generator.filenames
test_img = np.asarray(test_images)[errors]

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        idx = np.random.randint(0, len(test_img))
        true_index = y_true_errors[idx]
        true_label = labels[true_index]
        predicted_index = y_pred_errors[idx]
        predicted_label = labels[predicted_index]
        ax[i, j].set_title(f"True Label: {true_label} \n Predicted Label: {predicted_label}")
        img_path = os.path.join(test_dataset, test_img[idx])
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        ax[i, j].imshow(img)
        ax[i, j].axis("off")

plt.tight_layout()
plt.suptitle('Wrong Predictions made on test set', fontsize=20)
plt.show()
